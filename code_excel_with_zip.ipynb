# %%
import requests
import webbrowser
import pandas as pd
import os
from tqdm import tqdm
import zipfile
import glob
import subprocess  # Added for GitHub CLI

def check_readme_issues(model_data):
    """
    Check for issues with the README file.
    You can implement specific logic here.
    """
    readme = model_data.get("readme")

    if not readme:
        return "README missing"

    if not isinstance(readme, str):
        return "README is not a text file"

    # Add more checks as needed

    return "No issues"  # If no issues found

def check_zip_issues(zip_path):
    """
    Check for issues with the zip file.
    You can implement specific logic here.
    """
    issues = []

    try:
        with zipfile.ZipFile(zip_path, 'r') as zip_file:
            file_list = zip_file.namelist()

            # Check for issues
            if any('__pycache__'in file for file in file_list):
                issues.append("__pycache__ folder")
            for bad_folder in ('arm64/', 'i386/', 'x86_64/'):
                if any(bad_folder in file for file in file_list):
                    issues.append(f"Bad folder: {bad_folder}")
            for invalid_type in ('.so', '.dll', '.o', '.pyc'):
                if any(file.endswith(invalid_type) for file in file_list):
                    issues.append(f"Invalid file format: {invalid_type}")
            if any(file.startswith('__MACOSX/') for file in file_list):
                issues.append("__MACOSX folder")
            top_level_folders=set([file.split('/')[0] for file in file_list])
            if len(top_level_folders) > 1:
                issues.append("Multiple top-level folders")
            if any('DS_Store' in file for file in file_list):
                issues.append('DS_store')


    except Exception as e:
        issues.append(f"Error scanning zip file: {str(e)}")

    if not issues:
        return "No issues"

    return ", ".join(issues)

# %%
# Define the ModelDB API endpoint
api_url = "https://modeldb.science/api/v1/models"

# Make an API request to get the list of model IDs
response = requests.get(api_url)
data = response.json()

# Create a directory to store downloaded zip files
os.makedirs("zip_files", exist_ok=True)

# %%
# get all metadata
api_url = "https://modeldb.science/api/v1/models"
data_dict={}
for model_id in tqdm(data):
    # Fetch metadata for the model
    model_data = requests.get(f"{api_url}/{model_id}").json()
    data_dict[model_id]=model_data
# Out:
#   0%|          | 0/1828 [00:00<?, ?it/s]100%|██████████| 1828/1828 [04:05<00:00,  7.46it/s]

# %%
# Get all zip files (not necessary if they are already downloaded)

for model_id in tqdm(data):
    zip_url=f"https://modeldb.science/download/{model_id}"
    zip_filename = f"zip_files/{model_id}.zip"
    with open(zip_filename, 'wb') as zip_file:
        zip_response = requests.get(zip_url)
        zip_file.write(zip_response.content)
# Out:
#   9%|▉         | 172/1833 [01:31<14:42,  1.88it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3312\1760311435.py in <module>
#       5     zip_filename = f"zip_files/{model_id}.zip"
#       6     with open(zip_filename, 'wb') as zip_file:
# ----> 7         zip_response = requests.get(zip_url)
#       8         zip_file.write(zip_response.content)
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     487         try:
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#     491                     url=url,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1375         try:
#    1376             try:
# -> 1377                 response.begin()
#    1378             except ConnectionError:
#    1379                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     318         # read until we get a non-100 response
#     319         while True:
# --> 320             version, status, reason = self._read_status()
#     321             if status != CONTINUE:
#     322                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     279
#     280     def _read_status(self):
# --> 281         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282         if len(line) > _MAXLINE:
#     283             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241                   self.__class__)
# -> 1242             return self.read(nbytes, buffer)
#    1243         else:
#    1244             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1098         try:
#    1099             if buffer is not None:
# -> 1100                 return self._sslobj.read(len, buffer)
#    1101             else:
#    1102                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
#Iterate over all data and save to dataframe

# Create an empty list to store the data
data_list = []

# Initialize count variables
total_models = 0
github_models = 0
zip_issues_models = 0

# Iterate through model IDs
for model_id in tqdm(data):
    # Fetch metadata for the model
    model_data=data_dict[model_id]
    # Extract additional metadata
    modeling_application = ", ".join(item['object_name'] for item in model_data.get('modeling_application', {}).get('value', []))
    model_paper = ", ".join(item['object_name'] for item in model_data.get('model_paper', {}).get('value', []))
    implemented_by = ", ".join(item['object_name'] for item in model_data.get('implemented_by', {}).get('value', []))
    public_submitter_email = model_data.get('public_submitter_email', {}).get('value', '')
    simPFid = model_data.get('simPFid', {}).get('value', 0)
    has_modelview = model_data.get('has_modelview', {}).get('value', False)

    # Extract missing metadata
    model_type = ", ".join(item['object_name'] for item in model_data.get('model_type', {}).get('value', []))
    cell_types = ", ".join(item['object_name'] for item in model_data.get('neurons', {}).get('value', []))
    currents = ", ".join(item['object_name'] for item in model_data.get('currents', {}).get('value', []))
    model_concept = ", ".join(item['object_name'] for item in model_data.get('model_concept', {}).get('value', []))

    # Check if GitHub repository URL exists
    github_repo_url = f"https://github.com/modeldbrepository/{model_id}"
    github_repo_exists = requests.head(github_repo_url).status_code == 200

    # Check README issues
    readme_issues = check_readme_issues(model_data)

    # Check zip issues
    zip_filename = f"zip_files/{model_id}.zip"
    zip_issues = check_zip_issues(zip_filename)

    # Count models with zip issues
    if zip_issues != "No issues":
        zip_issues_models += 1

    # Increment the total count
    total_models += 1

    # Count models with GitHub repositories
    if github_repo_exists:
        github_models += 1

    # Append the data to the list
    data_list.append({
        "Model ID": model_id,
        "Model Type": model_type,
        "Cell Types": cell_types,
        "Currents": currents,
        "Model Concept": model_concept,
        "Modeling Application": modeling_application,
        "Model Paper": model_paper,
        "Implemented By": implemented_by,
        "Public Submitter Email": public_submitter_email,
        "simPFid": simPFid,
        "Has Modelview": has_modelview,
        "GitHub Repository Exists": github_repo_exists,
        "README Issues": readme_issues,
        "Zip Issues": zip_issues,
        "total metadata": len(model_data.items())
    })

# Create a single-row summary DataFrame
summary_data = [
    {
        "Total Models Processed": total_models,
        "Total Models with GitHub Repositories": github_models,
        "Total Models with Zip Issues": zip_issues_models
    }
]

# Add the summary data as the first row
data_list.insert(0, summary_data[0])

# Create a DataFrame from the list of data
df = pd.DataFrame(data_list)

# Export the DataFrame to Excel or CSV
with pd.ExcelWriter("modeldb_data_oct_5.xlsx", engine='xlsxwriter') as writer:
    df.to_excel(writer, sheet_name='Model Data', index=False)

# Print the summary
print("Data exported to Excel successfully.")
# Out:
# 100%|██████████| 1828/1828 [15:16<00:00,  2.00it/s]
# Data exported to Excel successfully.

# %% [markdown]
# Zipfile

# %%
import requests
from bs4 import BeautifulSoup

# Define the ModelDB URL to scrape
modeldb_url = "https://modeldb.science/"

# Send an HTTP GET request to the ModelDB URL
response = requests.get(modeldb_url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the HTML content of the page using BeautifulSoup
    soup = BeautifulSoup(response.text, "html.parser")

    # Find all the model links on the page
    model_links = soup.find_all("a", href=True)

    # Create a list to store model IDs and zip file URLs
    model_data_list = []

    # Iterate through the model links
    for link in model_links:
        href = link.get("href")
        if href.startswith("/model/"):
            model_id = href.split("/")[-1]
            zip_url = f"https://modeldb.science/model/{model_id}/files/{model_id}.zip"
            model_data_list.append({"Model ID": model_id, "Zip URL": zip_url})

    # Now, you have a list of model IDs and zip file URLs
    # You can modify your existing script to use this data for downloading and checking zip files

else:
    print("Failed to retrieve ModelDB page. Status code:", response.status_code)

# %%
# Define the ModelDB API endpoint
api_url = "https://modeldb.science/api/v1/models"

# Make an API request to get the list of model IDs
response = requests.get(api_url)
data = response.json()

# Create an empty list to store the data
data_list = []

# Create a directory to store downloaded zip files
os.makedirs("zip_files", exist_ok=True)

model_id=data[5]
model_id
# Out:
# 2796

# %%
zip_issues=[]
for model_id in data:
    zip_path=f"zip_files/{model_id}.zip"
    zip_issues.append(check_zip_issues(zip_path))

model_df=pd.read_excel("modeldb_data_1.xlsx")
model_df['new_zip_issues']=['']+zip_issues
model_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30916\3232780.py in <module>
#       4     zip_issues.append(check_zip_issues(zip_path))
#       5
# ----> 6 model_df=pd.read_excel("modeldb_data_1.xlsx")
#       7 model_df['new_zip_issues']=['']+zip_issues
#       8 model_df
#
# NameError: name 'pd' is not defined

# %%
for model_id in tqdm(data):
    zip_url=f"https://modeldb.science/download/{model_id}"
    zip_filename = f"zip_files/{model_id}.zip"
    with open(zip_filename, 'wb') as zip_file:
        zip_response = requests.get(zip_url)
        zip_file.write(zip_response.content)
# Out:
#  93%|█████████▎| 1709/1833 [13:33<00:59,  2.10it/s]
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      94     if err is not None:
# ---> 95         raise err
#      96
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      84                 sock.bind(source_address)
# ---> 85             sock.connect(sa)
#      86             return sock
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385         try:
# --> 386             self._validate_conn(conn)
#     387         except (SocketTimeout, BaseSSLError) as e:
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#    1041         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042             conn.connect()
#    1043
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     357         # Add certificate verification
# --> 358         self.sock = conn = self._new_conn()
#     359         hostname = self.host
#
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     185         except SocketError as e:
# --> 186             raise NewConnectionError(
#     187                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x00000137019B13D0>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#
# ~\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     786
# --> 787             retries = retries.increment(
#     788                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~\anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     591         if new_retry.is_exhausted():
# --> 592             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     593
#
# MaxRetryError: HTTPSConnectionPool(host='modeldb.science', port=443): Max retries exceeded with url: /download/267056 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000137019B13D0>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30916\2112387857.py in <module>
#       3     zip_filename = f"zip_files/{model_id}.zip"
#       4     with open(zip_filename, 'wb') as zip_file:
# ----> 5         zip_response = requests.get(zip_url)
#       6         zip_file.write(zip_response.content)
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     563                 raise SSLError(e, request=request)
#     564
# --> 565             raise ConnectionError(e, request=request)
#     566
#     567         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='modeldb.science', port=443): Max retries exceeded with url: /download/267056 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000137019B13D0>: Failed to establish a new connection: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond'))

# %%
new_data= pd.read_excel("modeldb_data_with_zip.xlsx")
new_data
# Out:
#       Total Models Processed  Total Models with GitHub Repositories  \
# 0                     1828.0                                 1493.0
# 1                        NaN                                    NaN
# 2                        NaN                                    NaN
# 3                        NaN                                    NaN
# 4                        NaN                                    NaN
# ...                      ...                                    ...
# 1824                     NaN                                    NaN
# 1825                     NaN                                    NaN
# 1826                     NaN                                    NaN
# 1827                     NaN                                    NaN
# 1828                     NaN                                    NaN
#
#       Total Models with Zip Issues   Model ID  \
# 0                              0.0        NaN
# 1                              NaN      279.0
# 2                              NaN     2487.0
# 3                              NaN     2488.0
# 4                              NaN     2730.0
# ...                            ...        ...
# 1824                           NaN  2014817.0
# 1825                           NaN   267599.0
# 1826                           NaN   267144.0
# 1827                           NaN  2014825.0
# 1828                           NaN   267618.0
#
#                                        Model Type  \
# 0                                             NaN
# 1     Neuron or other electrically excitable cell
# 2     Neuron or other electrically excitable cell
# 3     Neuron or other electrically excitable cell
# 4                               Realistic Network
# ...                                           ...
# 1824  Neuron or other electrically excitable cell
# 1825  Neuron or other electrically excitable cell
# 1826                                          NaN
# 1827                                          NaN
# 1828                                Extracellular
#
#                                              Cell Types  \
# 0                                                   NaN
# 1     Thalamus geniculate nucleus/lateral principal ...
# 2                   Olfactory bulb main mitral GLU cell
# 3     Neocortex L5/6 pyramidal GLU cell, Neocortex L...
# 4     Olfactory bulb main mitral GLU cell, Olfactory...
# ...                                                 ...
# 1824                           Cardiac ventricular cell
# 1825                 Hippocampus CA1 pyramidal GLU cell
# 1826  Abstract integrate-and-fire adaptive exponenti...
# 1827                                                NaN
# 1828                                  Myelinated neuron
#
#                                                Currents  \
# 0                                                   NaN
# 1                        I Na,t, I T low threshold, I K
# 2     I Na,t, I L high threshold, I A, I K, I K,leak...
# 3     I Na,t, I K, I M, I K,Ca, I Sodium, I Calcium,...
# 4     I Na,t, I L high threshold, I A, I K, I K,leak...
# ...                                                 ...
# 1824                                                NaN
# 1825                                            I TRPM4
# 1826                                                NaN
# 1827                                                NaN
# 1828                                                NaN
#
#                                           Model Concept  \
# 0                                                   NaN
# 1     Dendritic Action Potentials, Bursting, Ion Cha...
# 2       Parameter Fitting, Simplified Models, Olfaction
# 3     Activity Patterns, Active Dendrites, Influence...
# 4     Oscillations, Synchronization, Spatio-temporal...
# ...                                                 ...
# 1824                                  Action Potentials
# 1825                                                NaN
# 1826                                                NaN
# 1827  Learning, Reinforcement Learning, Synaptic Pla...
# 1828                               Extracellular Fields
#
#                 Modeling Application  \
# 0                                NaN
# 1                             NEURON
# 2                             NEURON
# 3                             NEURON
# 4                             NEURON
# ...                              ...
# 1824                          XPPAUT
# 1825                          NEURON
# 1826                          MATLAB
# 1827                          Python
# 1828  COMSOL, NEURON, MATLAB, Python
#
#                                             Model Paper  \
# 0                                                   NaN
# 1     Destexhe A, Neubig M, Ulrich D, Huguenard J (1...
# 2                    Davison AP, Feng J, Brown D (2000)
# 3                        Mainen ZF, Sejnowski TJ (1996)
# 4                    Davison AP, Feng J, Brown D (2003)
# ...                                                 ...
# 1824       Bueno-Orovio A, Cherry EM, Fenton FH. (2008)
# 1825  Combe CL, Upchurch CM, Canavier CC, Gasparini ...
# 1826               Maes A, Barahona M, Clopath C (2023)
# 1827                         Blackwell K, Doya K (2023)
# 1828  Xie Y, Qin P, Guo T, Al Abed A, Lovell NH, Tsa...
#
#                                          Implemented By  \
# 0                                                   NaN
# 1         Destexhe, Alain [Destexhe at iaf.cnrs-gif.fr]
# 2     Davison, Andrew [Andrew.Davison at iaf.cnrs-gi...
# 3                     Mainen, Zach [Mainen at cshl.edu]
# 4     Davison, Andrew [Andrew.Davison at iaf.cnrs-gi...
# ...                                                 ...
# 1824                                                NaN
# 1825                    Canavier, CC, Upchurch, Carol M
# 1826          Maes, Amadeus [amadeus.maes at gmail.com]
# 1827                                                NaN
# 1828                                                NaN
#
#           Public Submitter Email  simPFid  Has Modelview  \
# 0                            NaN      NaN            NaN
# 1                            NaN    275.0            1.0
# 2                            NaN    304.0            1.0
# 3                            NaN    315.0            1.0
# 4                            NaN    302.0            1.0
# ...                          ...      ...            ...
# 1824  071320@tool.caaumed.org.tw      0.0            0.0
# 1825           cupchu@lsuhsc.edu      0.0            0.0
# 1826      amadeus.maes@gmail.com      0.0            0.0
# 1827     kim-blackwell@uiowa.edu      0.0            0.0
# 1828      yuyang.xie@outlook.com      0.0            0.0
#
#       GitHub Repository Exists   README Issues             Zip Issues  \
# 0                          NaN             NaN                    NaN
# 1                          1.0  README missing  No zip file available
# 2                          1.0  README missing  No zip file available
# 3                          1.0  README missing  No zip file available
# 4                          1.0  README missing  No zip file available
# ...                        ...             ...                    ...
# 1824                       0.0  README missing  No zip file available
# 1825                       1.0  README missing  No zip file available
# 1826                       1.0  README missing  No zip file available
# 1827                       1.0  README missing  No zip file available
# 1828                       1.0  README missing  No zip file available
#
#                                          new_zip_issues
# 0                                                   NaN
# 1                                             No issues
# 2     __MACOSX folder found, Multiple top-level fold...
# 3                                             No issues
# 4     __MACOSX folder found, Multiple top-level fold...
# ...                                                 ...
# 1824                                          No issues
# 1825                          Invalid file format found
# 1826                                          No issues
# 1827                                          No issues
# 1828                                          No issues
#
# [1829 rows x 18 columns]

# %%
with zipfile.ZipFile(zip_path, 'r') as zip_file:
    file_list = zip_file.namelist()

# %%
file_list
# Out:
# ['267618/',
#  '267618/nerve/',
#  '267618/nerve/AFibreBuilder.hoc',
#  '267618/nerve/sciaticNerveCoords.txt',
#  '267618/nerve/fasciclesInfo.txt',
#  '267618/nerve/sciaticNerveBuilder.hoc',
#  '267618/nerve/CFibreBuilder.hoc',
#  '267618/nerve/fibreCoordsGen.m',
#  '267618/nerve/simpleFascicle.hoc',
#  '267618/nerve/simpleFibre.hoc',
#  '267618/example_sciaticNerve.py',
#  '267618/example_simple.py',
#  '267618/Makefile',
#  '267618/setrx.hoc',
#  '267618/COMSOL2NEURON_auto_conv.py',
#  '267618/NEURON2COMSOL_auto_conv.py',
#  '267618/scripts/',
#  '267618/scripts/Fig3_CFibreModelValidation.hoc',
#  '267618/scripts/Fig5_TIME_arrangement.py',
#  '267618/scripts/stimStrat.py',
#  '267618/scripts/Fig7_rampKFS.m',
#  '267618/scripts/Fig8_PE.m',
#  '267618/scripts/Fig8_PE_hex.py',
#  '267618/scripts/attachStim.hoc',
#  '267618/scripts/Fig6_KFS_AFibre.py',
#  '267618/scripts/Fig6_KFS.m',
#  '267618/scripts/Fig8_PE_mono.py',
#  '267618/scripts/Fig4_TIME_diam.py',
#  '267618/scripts/Fig3_AFibreModelValidation.hoc',
#  '267618/scripts/Fig7_rampKFS_tao.py',
#  '267618/scripts/firingRate.m',
#  '267618/scripts/Fig7_rampKFS_amp.py',
#  '267618/scripts/Fig3_ModelValidation.m',
#  '267618/scripts/Fig6_KFS_CFibre.py',
#  '267618/README.txt',
#  '267618/autoToolkit.py',
#  '267618/data/',
#  '267618/data/modelValidation/',
#  '267618/data/modelValidation/AFibreModelValidation.txt',
#  '267618/data/modelValidation/CFibreModelValidation.txt',
#  '267618/data/PE/',
#  '267618/data/PE/hex.txt',
#  '267618/data/PE/mono.txt',
#  '267618/data/rx/',
#  '267618/data/rx/rx_xtra_interpolated_mono.txt',
#  '267618/mod/',
#  '267618/mod/nahh.mod',
#  '267618/mod/kdr.mod',
#  '267618/mod/AXNODE.mod',
#  '267618/mod/Xtra.mod',
#  '267618/example_seperate.py']

# %%
with pd.ExcelWriter("modeldb_data_with_zip.xlsx", engine='xlsxwriter') as writer:
    model_df.to_excel(writer, sheet_name='Model Data', index=False)

# %% [markdown]
# ## Extra - README:

# %%
# go thought README's
import os
import requests
import pandas as pd
import webbrowser

# Define your custom CSV file name or path
csv_file_path = "progress_database.csv"  # Replace with your file name or path

# Check if the CSV file exists or create it if it doesn't
if not os.path.isfile(csv_file_path):
    # Create an empty DataFrame and save it as a CSV file
    df = pd.DataFrame(columns=['Model ID', 'Response'])
    df.to_csv(csv_file_path, index=False)

# Define the ModelDB API endpoint
api_url = "https://modeldb.science/api/v1/models"

# Function to open a webpage and record user response
def process_model(model_id, total_models, processed_models):
    # Open the ModelDB webpage for the current model
    model_page_url = f"https://modeldb.science/{model_id}"

    try:
        response = requests.get(model_page_url)
        response.raise_for_status()  # Raise an error if the page is not found
        webbrowser.open(model_page_url)
    except requests.exceptions.RequestException as e:
        print(f"Error opening the page for Model ID {model_id}: {str(e)}")
        return

    # Prompt the user for input ('n' or 'y' for issues, 'q' to quit)
    response = input(f"Model ID {model_id} ({processed_models}/{total_models}): "
                     "Press 'n' if no issues, 'y' if there are issues, 'q' to quit: ")

    if response.lower() == 'q':
        return -1  # User wants to quit
    elif response.lower() in ['n', 'y']:
        # Append the response to the CSV file
        data = pd.DataFrame({'Model ID': [model_id], 'Response': [response]})
        data.to_csv(csv_file_path, mode='a', header=False, index=False)

# Load the CSV file with progress data (if it exists)
df = pd.read_csv(csv_file_path)

# Make an API request to get the list of model IDs
response = requests.get(api_url)
data = response.json()

total_models = len(data)
processed_models = len(df)

# Process each model that hasn't been processed yet
for model_id in data:
    if model_id not in df['Model ID'].values:
        result = process_model(model_id, total_models, processed_models)
        if result == -1:
            print("User chose to quit.")
            break

print("Processing complete. You can continue from where you left off.")
# Out:
# Processing complete. You can continue from where you left off.

# %%
import pandas as pd

# Load the existing CSV file
csv_file_path = "progress_database.csv"  # Replace with your file name or path
df = pd.read_csv(csv_file_path)

# Update 'n' to 'NO ISSUE' and 'y' to 'ISSUE' (including models 118759, 127321, and 136296)
# Also, consider blanks as 'ISSUE'
df['Response'] = df['Response'].replace({'n': 'NO ISSUE', 'y': 'ISSUE', '': 'ISSUE', '118759': 'ISSUE', '127321': 'ISSUE', '136296': 'ISSUE'})

# Count the number of issues
issue_count = df['Response'].value_counts()

# Save the modified DataFrame back to the CSV file
df.to_csv(csv_file_path, index=False)

print("CSV file has been updated.")
print(f"Issues Count:\n{issue_count}")
# Out:
# CSV file has been updated.
# Issues Count:
# NO ISSUE    1668
# ISSUE        160
# Name: Response, dtype: int64

# %%
import pandas as pd

# Define the path to the CSV file
csv_file_path = "progress_database.csv"  # Update with your CSV file path

# Load the CSV file
df = pd.read_csv(csv_file_path)

# Filter entries with "ISSUE" in the "Response" column
issues_df = df[df['Response'].str.lower() == 'issue']

# Check if there are any issues to review
if issues_df.empty:
    print("No entries with 'ISSUE' found.")
else:
    # Get the last processed index, if available
    last_processed_index = 0
    if 'Last Processed Index' in issues_df.columns:
        last_processed_index = issues_df['Last Processed Index'].max()

    # Iterate through the issues and allow adding comments
    for index, row in issues_df.iterrows():
        if index <= last_processed_index:
            continue  # Skip already processed entries

        # Check if the "Comments" column is already populated
        if not pd.isna(row['Comments']):
            print(f"Model ID {row['Model ID']} already processed. Skipping...")
            continue

        model_id = row['Model ID']
        response = row['Response']
        model_link = f"https://modeldb.science/{model_id}"  # Add the link here

        print(f"Model ID {model_id}: {response}")
        print(f"Model Link: {model_link}")

        comment = input(f"Add a comment for Model ID {model_id} (or press 'q' to quit): ")

        if comment.lower() == 'q':
            print("Quitting...")
            break  # Exit the loop and script if 'q' is entered

        # Update the "Comments" column
        issues_df.loc[index, 'Comments'] = comment

        # Update the "Last Processed Index" column to track progress
        issues_df.loc[index, 'Last Processed Index'] = index

        # Save the updated DataFrame back to the CSV file after processing each entry
        issues_df.to_csv(csv_file_path, index=False)

        print(f"Model ID {model_id} processed.")

    print("All available entries processed.")

# Remove the "Last Processed Index" column before saving the final result
issues_df.drop(columns=['Last Processed Index'], inplace=True)
issues_df.to_csv(csv_file_path, index=False)

print("Comments saved to the CSV file.")
# Out:
# Model ID 3682 already processed. Skipping...
# Model ID 3808 already processed. Skipping...
# Model ID 7400 already processed. Skipping...
# Model ID 7485 already processed. Skipping...
# Model ID 8210 already processed. Skipping...
# Model ID 19698 already processed. Skipping...
# Model ID 20212 already processed. Skipping...
# Model ID 22203 already processed. Skipping...
# Model ID 36861 already processed. Skipping...
# Model ID 36869 already processed. Skipping...
# Model ID 36956 already processed. Skipping...
# Model ID 37103 already processed. Skipping...
# Model ID 37129 already processed. Skipping...
# Model ID 39949 already processed. Skipping...
# Model ID 50207 already processed. Skipping...
# Model ID 50219 already processed. Skipping...
# Model ID 50392 already processed. Skipping...
# Model ID 50656 already processed. Skipping...
# Model ID 51196 already processed. Skipping...
# Model ID 53425 already processed. Skipping...
# Model ID 53572 already processed. Skipping...
# Model ID 53894 already processed. Skipping...
# Model ID 53965 already processed. Skipping...
# Model ID 54141 already processed. Skipping...
# Model ID 55035 already processed. Skipping...
# Model ID 55273 already processed. Skipping...
# Model ID 55748 already processed. Skipping...
# Model ID 55756 already processed. Skipping...
# Model ID 55859 already processed. Skipping...
# Model ID 58172 already processed. Skipping...
# Model ID 62266 already processed. Skipping...
# Model ID 62272 already processed. Skipping...
# Model ID 62287 already processed. Skipping...
# Model ID 62654 already processed. Skipping...
# Model ID 62676 already processed. Skipping...
# Model ID 64242 already processed. Skipping...
# Model ID 64266 already processed. Skipping...
# Model ID 79238 already processed. Skipping...
# Model ID 79461 already processed. Skipping...
# Model ID 82385 already processed. Skipping...
# Model ID 82891 already processed. Skipping...
# Model ID 83472 already processed. Skipping...
# Model ID 84627 already processed. Skipping...
# Model ID 84641 already processed. Skipping...
# Model ID 84649 already processed. Skipping...
# Model ID 85981 already processed. Skipping...
# Model ID 86537 already processed. Skipping...
# Model ID 87450 already processed. Skipping...
# Model ID 93416 already processed. Skipping...
# Model ID 95990 already processed. Skipping...
# Model ID 102871 already processed. Skipping...
# Model ID 110022 already processed. Skipping...
# Model ID 112922 already processed. Skipping...
# Model ID 113426 already processed. Skipping...
# Model ID 114450 already processed. Skipping...
# Model ID 114637 already processed. Skipping...
# Model ID 115813 already processed. Skipping...
# Model ID 116312 already processed. Skipping...
# Model ID 116313 already processed. Skipping...
# Model ID 116606 already processed. Skipping...
# Model ID 116740 already processed. Skipping...
# Model ID 116983 already processed. Skipping...
# Model ID 117351 already processed. Skipping...
# Model ID 118524 already processed. Skipping...
# Model ID 124043 already processed. Skipping...
# Model ID 125855 already processed. Skipping...
# Model ID 126052 already processed. Skipping...
# Model ID 126096 already processed. Skipping...
# Model ID 126371 already processed. Skipping...
# Model ID 126389 already processed. Skipping...
# Model ID 126392 already processed. Skipping...
# Model ID 126489 already processed. Skipping...
# Model ID 126598 already processed. Skipping...
# Model ID 127996: ISSUE
# Model Link: https://modeldb.science/127996
# Add a comment for Model ID 127996 (or press 'q' to quit): Link page to the model - 404 error - the only link found is for the paper - https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2954316/
# Model ID 127996 processed.
# Model ID 137745: ISSUE
# Model Link: https://modeldb.science/137745
# Add a comment for Model ID 137745 (or press 'q' to quit): model customization section link - page not found
# Model ID 137745 processed.
# Model ID 138273: ISSUE
# Model Link: https://modeldb.science/138273
# Add a comment for Model ID 138273 (or press 'q' to quit): modeldb.science refused to connect.
# Model ID 138273 processed.
# Model ID 138631: ISSUE
# Model Link: https://modeldb.science/138631
# Add a comment for Model ID 138631 (or press 'q' to quit): Software download - not working + Link to the paper  - ERROR 404 - new link - https://pubmed.ncbi.nlm.nih.gov/20044893/
# Model ID 138631 processed.
# Model ID 139654: ISSUE
# Model Link: https://modeldb.science/139654
# Add a comment for Model ID 139654 (or press 'q' to quit): modeldb.science refused to connect.
# Model ID 139654 processed.
# Model ID 140599: ISSUE
# Model Link: https://modeldb.science/140599
# Add a comment for Model ID 140599 (or press 'q' to quit): The DipoleLocalizationKit archives link - page not found
# Model ID 140599 processed.
# Model ID 140964: ISSUE
# Model Link: https://modeldb.science/140964
# Add a comment for Model ID 140964 (or press 'q' to quit): web-link to a network model and simulator - not found - no new one was found as well - possible new one - https://dblp.org/pid/73/4404.html
# Model ID 140964 processed.
# Model ID 141835: ISSUE
# Model Link: https://modeldb.science/141835
# Add a comment for Model ID 141835 (or press 'q' to quit): HTML link - not loading
# Model ID 141835 processed.
# Model ID 143446: ISSUE
# Model Link: https://modeldb.science/143446
# Add a comment for Model ID 143446 (or press 'q' to quit): Link -  not found - possible new link - http://genesis-sim.org/GENESIS/hbtn2e-bower-etal/hbtn2e-bower-etal.html
# Model ID 143446 processed.
# Model ID 144499: ISSUE
# Model Link: https://modeldb.science/144499
# Add a comment for Model ID 144499 (or press 'q' to quit): Pylab terminal link - not currently available - possible new link - https://jakevdp.github.io/mpl_tutorial/tutorial_pages/tut1.html
# Model ID 144499 processed.
# Model ID 144570: ISSUE
# Model Link: https://modeldb.science/144570
# Add a comment for Model ID 144570 (or press 'q' to quit): Link - not found - no new ones were able to be found
# Model ID 144570 processed.
# Model ID 147103: ISSUE
# Model Link: https://modeldb.science/147103
# Add a comment for Model ID 147103 (or press 'q' to quit): New link - https://pubmed.ncbi.nlm.nih.gov/23197532/
# Model ID 147103 processed.
# Model ID 147218: ISSUE
# Model Link: https://modeldb.science/147218
# Add a comment for Model ID 147218 (or press 'q' to quit): Images not loading
# Model ID 147218 processed.
# Model ID 147366: ISSUE
# Model Link: https://modeldb.science/147366
# Add a comment for Model ID 147366 (or press 'q' to quit): Link - page not found
# Model ID 147366 processed.
# Model ID 147740: ISSUE
# Model Link: https://modeldb.science/147740
# Add a comment for Model ID 147740 (or press 'q' to quit): Links - page not found
# Model ID 147740 processed.
# Model ID 147757: ISSUE
# Model Link: https://modeldb.science/147757
# Add a comment for Model ID 147757 (or press 'q' to quit): modeldb.science refused to connect.
# Model ID 147757 processed.
# Model ID 148094: ISSUE
# Model Link: https://modeldb.science/148094
# Add a comment for Model ID 148094 (or press 'q' to quit): modeldb.science refused to connect.
# Model ID 148094 processed.
# Model ID 150217: ISSUE
# Model Link: https://modeldb.science/150217
# Add a comment for Model ID 150217 (or press 'q' to quit): HTML link - not found - possible new link - https://github.com/robclewley/xpp-matlab
# Model ID 150217 processed.
# Model ID 150240: ISSUE
# Model Link: https://modeldb.science/150240
# Add a comment for Model ID 150240 (or press 'q' to quit): Alternate links- not found - no new ones were found
# Model ID 150240 processed.
# Model ID 150635: ISSUE
# Model Link: https://modeldb.science/150635
# Add a comment for Model ID 150635 (or press 'q' to quit): Link - page not found
# Model ID 150635 processed.
# Model ID 150698: ISSUE
# Model Link: https://modeldb.science/150698
# Add a comment for Model ID 150698 (or press 'q' to quit): Weird README output - look like a html file
# Model ID 150698 processed.
# Model ID 151681: ISSUE
# Model Link: https://modeldb.science/151681
# Add a comment for Model ID 151681 (or press 'q' to quit): Links - Page not found (404)
# Model ID 151681 processed.
# Model ID 152028: ISSUE
# Model Link: https://modeldb.science/152028
# Add a comment for Model ID 152028 (or press 'q' to quit): link not working PANDORA 1.3b - possible new link - https://github.com/cengique/pandora-matlab
# Model ID 152028 processed.
# Model ID 152113: ISSUE
# Model Link: https://modeldb.science/152113
# Add a comment for Model ID 152113 (or press 'q' to quit): New link for XPPAUT - https://sites.math.duke.edu/ode-book/xppaut/installation.html
# Model ID 152113 processed.
# Model ID 152625: ISSUE
# Model Link: https://modeldb.science/152625
# Add a comment for Model ID 152625 (or press 'q' to quit): New paper link - https://bmcmededuc.biomedcentral.com/articles/10.1186/1472-6920-13-70 - hoc code - link new one not found
# Model ID 152625 processed.
# Model ID 153633: ISSUE
# Model Link: https://modeldb.science/153633
# Add a comment for Model ID 153633 (or press 'q' to quit): HTML link for paper - not found - new one - https://pubmed.ncbi.nlm.nih.gov/10490941/
# Model ID 153633 processed.
# Model ID 153635: ISSUE
# Model Link: https://modeldb.science/153635
# Add a comment for Model ID 153635 (or press 'q' to quit): HTML link for paper - not found - new one - https://pubmed.ncbi.nlm.nih.gov/16014787/
# Model ID 153635 processed.
# Model ID 153985: ISSUE
# Model Link: https://modeldb.science/153985
# Add a comment for Model ID 153985 (or press 'q' to quit): HTML link for paper - not found - new one - https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6623863/
# Model ID 153985 processed.
# Model ID 153988: ISSUE
# Model Link: https://modeldb.science/153988
# Add a comment for Model ID 153988 (or press 'q' to quit): HTML link for paper - not found - new one -https://pubmed.ncbi.nlm.nih.gov/10591212/
# Model ID 153988 processed.
# Model ID 153998: ISSUE
# Model Link: https://modeldb.science/153998
# Add a comment for Model ID 153998 (or press 'q' to quit): HTML link for paper - not found - new one - https://pubmed.ncbi.nlm.nih.gov/21573200/
# Model ID 153998 processed.
# Model ID 154198: ISSUE
# Model Link: https://modeldb.science/154198
# Add a comment for Model ID 154198 (or press 'q' to quit): HTML link for paper - not found - new one - https://journals.aps.org/prl/abstract/10.1103/PhysRevLett.84.5668
# Model ID 154198 processed.
# Model ID 154288: ISSUE
# Model Link: https://modeldb.science/154288
# Add a comment for Model ID 154288 (or press 'q' to quit): HTML link for paper - not found - new one - https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2701607/
# Model ID 154288 processed.
# Model ID 154293: ISSUE
# Model Link: https://modeldb.science/154293
# Add a comment for Model ID 154293 (or press 'q' to quit): HTML link for paper - not found - new one - https://pubmed.ncbi.nlm.nih.gov/12590808/
# Model ID 154293 processed.
# Model ID 154348: ISSUE
# Model Link: https://modeldb.science/154348
# Add a comment for Model ID 154348 (or press 'q' to quit): HTML link for paper - not found - new one - https://pubmed.ncbi.nlm.nih.gov/21775612/
# Model ID 154348 processed.
# Model ID 154872: ISSUE
# Model Link: https://modeldb.science/154872
# Add a comment for Model ID 154872 (or press 'q' to quit): Links to see data - page not found
# Model ID 154872 processed.
# Model ID 155731: ISSUE
# Model Link: https://modeldb.science/155731
# Add a comment for Model ID 155731 (or press 'q' to quit): Zip link - Page not found
# Model ID 155731 processed.
# Model ID 156260: ISSUE
# Model Link: https://modeldb.science/156260
# Add a comment for Model ID 156260 (or press 'q' to quit): Links - Page not found - possible new link - https://www.mathworks.com/help/deeplearning/ref/network.train.html
# Model ID 156260 processed.
# Model ID 168310: ISSUE
# Model Link: https://modeldb.science/168310
# Add a comment for Model ID 168310 (or press 'q' to quit): New link - https://www.neuron.yale.edu/neuron/
# Model ID 168310 processed.
# Model ID 168591: ISSUE
# Model Link: https://modeldb.science/168591
# Add a comment for Model ID 168591 (or press 'q' to quit): Link - page not found
# Model ID 168591 processed.
# Model ID 180372: ISSUE
# Model Link: https://modeldb.science/180372
# Add a comment for Model ID 180372 (or press 'q' to quit): No issues
# Model ID 180372 processed.
# Model ID 182785: ISSUE
# Model Link: https://modeldb.science/182785
# Add a comment for Model ID 182785 (or press 'q' to quit): Link - Page not found
# Model ID 182785 processed.
# Model ID 182797: ISSUE
# Model Link: https://modeldb.science/182797
# Add a comment for Model ID 182797 (or press 'q' to quit): No issue
# Model ID 182797 processed.
# Model ID 183014: ISSUE
# Model Link: https://modeldb.science/183014
# Add a comment for Model ID 183014 (or press 'q' to quit): Zip link - page not found
# Model ID 183014 processed.
# Model ID 183017: ISSUE
# Model Link: https://modeldb.science/183017
# Add a comment for Model ID 183017 (or press 'q' to quit): Links - page not found - possible new link - https://elifesciences.org/articles/06444
# Model ID 183017 processed.
# Model ID 183077: ISSUE
# Model Link: https://modeldb.science/183077
# Add a comment for Model ID 183077 (or press 'q' to quit): Zip link - page not found
# Model ID 183077 processed.
# Model ID 184479: ISSUE
# Model Link: https://modeldb.science/184479
# Add a comment for Model ID 184479 (or press 'q' to quit): All links - pages not found - possible new link - https://www.frontiersin.org/articles/10.3389/fninf.2015.00025/full
# Model ID 184479 processed.
# Model ID 184732: ISSUE
# Model Link: https://modeldb.science/184732
# Add a comment for Model ID 184732 (or press 'q' to quit): New link - https://www.hws.edu/faculty/fietkiewicz-chris.aspx
# Model ID 184732 processed.
# Model ID 194881: ISSUE
# Model Link: https://modeldb.science/194881
# Add a comment for Model ID 194881 (or press 'q' to quit): Code link - page not found - could not find a new one
# Model ID 194881 processed.
# Model ID 194882: ISSUE
# Model Link: https://modeldb.science/194882
# Add a comment for Model ID 194882 (or press 'q' to quit): Code link - not available - new one could not be found
# Model ID 194882 processed.
# Model ID 206256: ISSUE
# Model Link: https://modeldb.science/206256
# Add a comment for Model ID 206256 (or press 'q' to quit): Data sheet pdf - link not working - but the data could be downloaded from the paper link
# Model ID 206256 processed.
# Model ID 222715: ISSUE
# Model Link: https://modeldb.science/222715
# Add a comment for Model ID 222715 (or press 'q' to quit): New link - https://sites.pitt.edu/~phase/bard/bardware/xpp/xpp.html
# Model ID 222715 processed.
# Model ID 225075: ISSUE
# Model Link: https://modeldb.science/225075
# Add a comment for Model ID 225075 (or press 'q' to quit): No issues
# Model ID 225075 processed.
# Model ID 225552: ISSUE
# Model Link: https://modeldb.science/225552
# Add a comment for Model ID 225552 (or press 'q' to quit): New link - https://core.ac.uk/reader/144729570
# Model ID 225552 processed.
# Model ID 226401: ISSUE
# Model Link: https://modeldb.science/226401
# Add a comment for Model ID 226401 (or press 'q' to quit): Images not loading
# Model ID 226401 processed.
# Model ID 226422: ISSUE
# Model Link: https://modeldb.science/226422
# Add a comment for Model ID 226422 (or press 'q' to quit): HTML link - not found
# Model ID 226422 processed.
# Model ID 226432: ISSUE
# Model Link: https://modeldb.science/226432
# Add a comment for Model ID 226432 (or press 'q' to quit): Images not found - and the README is in Japanese
# Model ID 226432 processed.
# Model ID 230326: ISSUE
# Model Link: https://modeldb.science/230326
# Add a comment for Model ID 230326 (or press 'q' to quit): Hay paper link - https://pubmed.ncbi.nlm.nih.gov/21829333/
# Model ID 230326 processed.
# Model ID 230929: ISSUE
# Model Link: https://modeldb.science/230929
# Add a comment for Model ID 230929 (or press 'q' to quit): Zip file - not loading
# Model ID 230929 processed.
# Model ID 232876: ISSUE
# Model Link: https://modeldb.science/232876
# Add a comment for Model ID 232876 (or press 'q' to quit): Additional note link - not available - no new was found
# Model ID 232876 processed.
# Model ID 234992: ISSUE
# Model Link: https://modeldb.science/234992
# Add a comment for Model ID 234992 (or press 'q' to quit): # README # - has one line
# Model ID 234992 processed.
# Model ID 235774: ISSUE
# Model Link: https://modeldb.science/235774
# Add a comment for Model ID 235774 (or press 'q' to quit): New HTML file - https://sites.pitt.edu/~phase/bard/bardware/xpp/xpp.html
# Model ID 235774 processed.
# Model ID 236306: ISSUE
# Model Link: https://modeldb.science/236306
# Add a comment for Model ID 236306 (or press 'q' to quit): New link for data - https://spiral.imperial.ac.uk/handle/10044/1/44555
# Model ID 236306 processed.
# Model ID 238347: ISSUE
# Model Link: https://modeldb.science/238347
# Add a comment for Model ID 238347 (or press 'q' to quit): Model data zip - page not found
# Model ID 238347 processed.
# Model ID 238920: ISSUE
# Model Link: https://modeldb.science/238920
# Add a comment for Model ID 238920 (or press 'q' to quit): No issues
# Model ID 238920 processed.
# Model ID 241796: ISSUE
# Model Link: https://modeldb.science/241796
# Add a comment for Model ID 241796 (or press 'q' to quit): No issues
# Model ID 241796 processed.
# Model ID 241826: ISSUE
# Model Link: https://modeldb.science/241826
# Add a comment for Model ID 241826 (or press 'q' to quit): New supplementary link - https://royalsocietypublishing.org/doi/suppl/10.1098/rsif.2017.0425
# Model ID 241826 processed.
# Model ID 243212: ISSUE
# Model Link: https://modeldb.science/243212
# Add a comment for Model ID 243212 (or press 'q' to quit): Supplementary could be downloaded from here the link on the page is not working - https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6001263/
# Model ID 243212 processed.
# Model ID 243508: ISSUE
# Model Link: https://modeldb.science/243508
# Add a comment for Model ID 243508 (or press 'q' to quit): The README in format of the HTML file
# Model ID 243508 processed.
# Model ID 247209: ISSUE
# Model Link: https://modeldb.science/247209
# Add a comment for Model ID 247209 (or press 'q' to quit): New link for Dendritic Low-Threshold paper - https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6793130/
# Model ID 247209 processed.
# Model ID 257027: ISSUE
# Model Link: https://modeldb.science/257027
# Add a comment for Model ID 257027 (or press 'q' to quit): modeldb.science refused to connect.
# Model ID 257027 processed.
# Model ID 257610: ISSUE
# Model Link: https://modeldb.science/257610
# Add a comment for Model ID 257610 (or press 'q' to quit): README - Forbidden
# Model ID 257610 processed.
# Model ID 259366: ISSUE
# Model Link: https://modeldb.science/259366
# Add a comment for Model ID 259366 (or press 'q' to quit): Figures - are not available/ not shown
# Model ID 259366 processed.
# Model ID 261714: ISSUE
# Model Link: https://modeldb.science/261714
# Add a comment for Model ID 261714 (or press 'q' to quit): modeldb.science refused to connect.
# Model ID 261714 processed.
# Model ID 263042: ISSUE
# Model Link: https://modeldb.science/263042
# Add a comment for Model ID 263042 (or press 'q' to quit): The README just says this - # SK_Slo_Paper
# Model ID 263042 processed.
# Model ID 263074: ISSUE
# Model Link: https://modeldb.science/263074
# Add a comment for Model ID 263074 (or press 'q' to quit): he code and executive file in Delphi-Pascal link - not shared - 404 error
# Model ID 263074 processed.
# Model ID 264844: ISSUE
# Model Link: https://modeldb.science/264844
# Add a comment for Model ID 264844 (or press 'q' to quit): README - is in the HTML format
# Model ID 264844 processed.
# Model ID 266551: ISSUE
# Model Link: https://modeldb.science/266551
# Add a comment for Model ID 266551 (or press 'q' to quit): Figures are missing - now shown
# Model ID 266551 processed.
# Model ID 266837: ISSUE
# Model Link: https://modeldb.science/266837
# Add a comment for Model ID 266837 (or press 'q' to quit): README - just shows the value of the "# Delays"
# Model ID 266837 processed.
# Model ID 266848: ISSUE
# Model Link: https://modeldb.science/266848
# Add a comment for Model ID 266848 (or press 'q' to quit): modeldb.science refused to connect.
# Model ID 266848 processed.
# Model ID 266900: ISSUE
# Model Link: https://modeldb.science/266900
# Add a comment for Model ID 266900 (or press 'q' to quit): README - just shows the values
# Model ID 266900 processed.
# Model ID 267073: ISSUE
# Model Link: https://modeldb.science/267073
# Add a comment for Model ID 267073 (or press 'q' to quit): README - list out the files (".py", *.dat *.npz *.sasparams)
# Model ID 267073 processed.
# Model ID 267132: ISSUE
# Model Link: https://modeldb.science/267132
# Add a comment for Model ID 267132 (or press 'q' to quit): modeldb.science refused to connect.
# Model ID 267132 processed.
# Model ID 267140: ISSUE
# Model Link: https://modeldb.science/267140
# Add a comment for Model ID 267140 (or press 'q' to quit): Image not shown
# Model ID 267140 processed.
# Model ID 267184: ISSUE
# Model Link: https://modeldb.science/267184
# Add a comment for Model ID 267184 (or press 'q' to quit): README - Changelog:  2023-02-06 Fix 9.0.0 error: <var> used as both variable and function in file module1_2.mod
# Model ID 267184 processed.
# Model ID 267286: ISSUE
# Model Link: https://modeldb.science/267286
# Add a comment for Model ID 267286 (or press 'q' to quit): README - just shows Notebook Content
# Model ID 267286 processed.
# Model ID 267338: ISSUE
# Model Link: https://modeldb.science/267338
# Add a comment for Model ID 267338 (or press 'q' to quit): README lists Figures, but no figures available
# Model ID 267338 processed.
# All available entries processed.
# Comments saved to the CSV file.

# %% [markdown]
# # Zip Files

# %%
import pandas as pd

# Load the Excel file into a DataFrame
file_path = "C:\\Users\\polin\\Downloads\\modeldb_data_2.xlsx"
df = pd.read_excel(file_path)

# Extract the "Zip Issues" column and count unique values
zip_issues_column = df["Zip Issues"]
unique_zip_issues = zip_issues_column.value_counts()

# Display the unique values and their frequencies
print("Unique Zip Issues and Frequencies:")
for issue, frequency in unique_zip_issues.items():
    print(f"Issue: {issue}, Frequency: {frequency}")
# Out:
# Unique Zip Issues and Frequencies:
# Issue: No issues, Frequency: 1472
# Issue: __MACOSX folder, Multiple top-level folders, Frequency: 183
# Issue: __MACOSX folder, Multiple top-level folders, DS_store, Frequency: 41
# Issue: DS_store, Frequency: 40
# Issue: Invalid file format: .pyc, Frequency: 18
# Issue: Invalid file format: .dll, Frequency: 15
# Issue: Invalid file format: .o, Frequency: 8
# Issue: Multiple top-level folders, Frequency: 8
# Issue: __pycache__ folder, Invalid file format: .pyc, Frequency: 4
# Issue: Invalid file format: .dll, Invalid file format: .o, Frequency: 4
# Issue: Invalid file format: .dll, Invalid file format: .o, __MACOSX folder, Multiple top-level folders, Frequency: 3
# Issue: Invalid file format: .dll, __MACOSX folder, Multiple top-level folders, Frequency: 3
# Issue: Bad folder: x86_64/, Invalid file format: .so, Invalid file format: .o, Frequency: 3
# Issue: Invalid file format: .o, __MACOSX folder, Multiple top-level folders, Frequency: 2
# Issue: Invalid file format: .pyc, __MACOSX folder, Multiple top-level folders, Frequency: 2
# Issue: Invalid file format: .dll, __MACOSX folder, Multiple top-level folders, DS_store, Frequency: 2
# Issue: Invalid file format: .pyc, DS_store, Frequency: 2
# Issue: Bad folder: x86_64/, Invalid file format: .so, Invalid file format: .o, DS_store, Frequency: 2
# Issue: Invalid file format: .o, DS_store, Frequency: 2
# Issue: Error scanning zip file: File is not a zip file, Frequency: 2
# Issue: __pycache__ folder, Invalid file format: .pyc, __MACOSX folder, Multiple top-level folders, Frequency: 2
# Issue: Invalid file format: .pyc, __MACOSX folder, Multiple top-level folders, DS_store, Frequency: 1
# Issue: __pycache__ folder, Invalid file format: .so, Invalid file format: .pyc, __MACOSX folder, Multiple top-level folders, Frequency: 1
# Issue: Invalid file format: .so, Invalid file format: .o, Multiple top-level folders, Frequency: 1
# Issue: Invalid file format: .so, DS_store, Frequency: 1
# Issue: __pycache__ folder, Invalid file format: .so, Invalid file format: .pyc, Frequency: 1
# Issue: Bad folder: x86_64/, Invalid file format: .so, Invalid file format: .o, __MACOSX folder, Multiple top-level folders, Frequency: 1
# Issue: Invalid file format: .so, Frequency: 1
# Issue: Bad folder: x86_64/, Invalid file format: .so, Invalid file format: .o, Invalid file format: .pyc, Frequency: 1
# Issue: Bad folder: x86_64/, Frequency: 1
# Issue: Invalid file format: .so, __MACOSX folder, Multiple top-level folders, DS_store, Frequency: 1

# %%
import requests
import os
import zipfile
import shutil
from tqdm import tqdm

def check_zip_issues(zip_path):
    """
    Check for issues with the zip file.
    You can implement specific logic here.
    """
    issues = []

    try:
        with zipfile.ZipFile(zip_path, 'r') as zip_file:
            file_list = zip_file.namelist()

            # Check for issues
            if any(file.startswith('__MACOSX/') for file in file_list):
                issues.append("__MACOSX folder")
            top_level_folders = set([file.split('/')[0] for file in file_list])
            if len(top_level_folders) > 1:
                issues.append("Multiple top-level folders")

            # Check for issues related to file formats
            invalid_file_formats = ['.pyc', '.dll', '.o', '.so']
            for file in file_list:
                file_extension = os.path.splitext(file)[-1]
                if file_extension in invalid_file_formats:
                    issues.append(f"Invalid file format: {file_extension}")
                if file.endswith('.DS_Store'):
                    issues.append('DS_Store')
                    
                # And bad folders
                bad_folders=['__MACOSX', '__pycache__','x86_64']
                for fold in bad_folders:
                    if fold in file.split('/'):
                        issues.append(f"Bad Folder: {fold}")        
        
            

    except Exception as e:
        issues.append(f"Error scanning zip file: {str(e)}")

    if not issues:
        return "No issues"

    return ", ".join(list(set(issues)))

# %%
# Get zip files
# Define the ModelDB API endpoint
api_url = "https://modeldb.science/api/v1/models"

# Make an API request to get the list of model IDs
response = requests.get(api_url)
data = response.json()

# Create a directory to store downloaded zip files
os.makedirs("zip_files", exist_ok=True)

# Download ZIP files if they are not already downloaded
for model_id in tqdm(data, desc="Downloading ZIP files"):
    zip_path = f"zip_files/{model_id}.zip"
    if not os.path.exists(zip_path):
        zip_url = f"https://modeldb.science/download/{model_id}"
        with open(zip_path, 'wb') as zip_file:
            zip_response = requests.get(zip_url, stream=True)
            zip_file.write(zip_response.content)
# Out:
# Downloading ZIP files: 100%|██████████| 1839/1839 [00:36<00:00, 49.73it/s]

# %%
# Create a directory to store cleaned ZIP files
os.makedirs("cleaned_zip_files", exist_ok=True)

# Iterate over ZIP files and clean them
for model_id in tqdm(data, desc="Cleaning ZIP files"):
    zip_path = f"zip_files/{model_id}.zip"
    zip_issues = check_zip_issues(zip_path)

    if zip_issues == "No issues":
        #shutil.copy(zip_path, f"cleaned_zip_files/{model_id}.zip")
        pass
    else:
        # Create a temporary directory to extract the ZIP file
        temp_dir = f"temp_zip_extract_{model_id}"
        os.makedirs(temp_dir, exist_ok=True)

        try:
            with zipfile.ZipFile(zip_path, 'r') as zip_file:
                zip_file.extractall(temp_dir)

            # Delete "__MACOSX" folders and their contents
            macosx_dir = os.path.join(temp_dir, "__MACOSX")
            if os.path.exists(macosx_dir):
                shutil.rmtree(macosx_dir)
            
            # Delete files with undesired extensions
            bad_files = []
            for ext in ('.pyc', '.dll', '.o', '.so'):
               bad_files.extend(glob.iglob(f"{temp_dir}/**/*{ext}", recursive=True))
            bad_files.extend(glob.iglob(f"{temp_dir}/**/.DS_Store", recursive=True))
            bad_folders=[]
            for bad_fold in ('__MACOSX', '__pycache__', 'x86_64'):
                bad_folders.extend(glob.iglob(f"{temp_dir}/**/{bad_fold}", recursive=True))

            for bad_file in bad_files:
                os.remove(bad_file)
            for bad_folder in bad_folders:
                shutil.rmtree(bad_folder)
                        
            # Combine multiple top level folders into one top level folder
            file_list=os.listdir(temp_dir)
            top_level_folders = set([file.split('/')[0] for file in file_list])
            if len(top_level_folders) > 1:
                new_top=f"{temp_dir}/All"
                os.makedirs(new_top, exist_ok=True)
                for top_folder in top_level_folders:
                    shutil.move(f"{temp_dir}/{top_folder}", new_top)
            
            # Create a new cleaned ZIP file
            cleaned_zip_path = f"cleaned_zip_files/{model_id}.zip"
            with zipfile.ZipFile(cleaned_zip_path, 'w', zipfile.ZIP_DEFLATED) as new_zip:
                for root, _, files in os.walk(temp_dir):
                    for file in files:
                        file_path = os.path.join(root, file)
                        arcname = os.path.relpath(file_path, temp_dir)
                        new_zip.write(file_path, arcname)

        except Exception as e:
            print(f"Error processing ZIP file {model_id}: {str(e)}")
        finally:
            # Clean up temporary directory
            shutil.rmtree(temp_dir)

print("ZIP files cleaned and saved in 'cleaned_zip_files' directory.")
# A few zip files do not copy for various reasons and will throw errors, those have been manually copied and fixed
# Two zip files that came from the API were empty, those have been manually downloaded and fixed as well.
# Out:
# Cleaning ZIP files:  53%|█████▎    | 967/1839 [03:05<04:08,  3.51it/s]
# Error processing ZIP file 168950: [Errno 2] No such file or directory: 'temp_zip_extract_168950\\RoessertEtAl2015\\publish\\closedloop\\figures\\fig52l_randomnet_ifun2b_0tau1v50_1tau1v1_2tau1v50_1wv0.1_2wv0.003_2varw0.1_2probw0.5_0N1000_1N100_ihsigma0.1_noinv_lentrain10_alpha0.0001_fitlasso_amod0.1_cnoise_vec0w_m.pdf'
# Cleaning ZIP files:  80%|████████  | 1473/1839 [05:51<02:15,  2.70it/s]
# Error processing ZIP file 256140: [Errno 13] Permission denied: 'temp_zip_extract_256140\\LuqueEtAl2019'
# Cleaning ZIP files: 100%|██████████| 1839/1839 [10:02<00:00,  3.05it/s]
# Error processing ZIP file 2014996: [Errno 2] No such file or directory: 'zip_files/2014996.zip'
# Error processing ZIP file 2015413: [Errno 2] No such file or directory: 'zip_files/2015413.zip'
# Error processing ZIP file 2015412: [Errno 2] No such file or directory: 'zip_files/2015412.zip'
# Error processing ZIP file 2015421: [Errno 2] No such file or directory: 'zip_files/2015421.zip'
# Error processing ZIP file 2014998: [Errno 2] No such file or directory: 'zip_files/2014998.zip'
# Error processing ZIP file 2014833: [Errno 2] No such file or directory: 'zip_files/2014833.zip'
# ZIP files cleaned and saved in 'cleaned_zip_files' directory.

# %%
# Confirm that all zip issues are fixed

zip_issues=[]
for model_id in tqdm(data):
    zip_path=f"cleaned_zip_files/{model_id}.zip"
    zip_issues=check_zip_issues(zip_path)
    if zip_issues != "No issues":
        print(model_id)
        print(zip_issues)
# Out:
# 100%|██████████| 1833/1833 [00:01<00:00, 1469.54it/s]

# %%
from git import Repo
import requests
import os
import zipfile
import shutil
from tqdm import tqdm

api_url = "https://modeldb.science/api/v1/models"

# Make an API request to get the list of model IDs
response = requests.get(api_url)
data = response.json()

os.makedirs("new_repos", exist_ok=True)

token='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'
for model_id in tqdm(data, desc="Uploading models to github"):
    zip_path = f'cleaned_zip_files/{model_id}.zip'
    if model_id<=267391:
        continue
    if not os.path.exists(zip_path):
        continue
    # Clone the repository
    repo_url = f"https://{token}@github.com/ModelDBRepository/{model_id}.git"
    local_repo_path = f'new_repos/{model_id}'
    try:
        repo = Repo.clone_from(repo_url, local_repo_path)
    except Exception as e:
            print(f"Error processing ID {model_id}: {str(e)}")
            continue


    # Remove all existing files in the Git directory
    for item in os.listdir(local_repo_path):
        item_path = os.path.join(local_repo_path, item)
        if item != '.git':
            if os.path.isfile(item_path):
                os.remove(item_path)
            elif os.path.isdir(item_path):
                shutil.rmtree(item_path)

    # Copy new files into the Git directory
    temp_dir = f"temp_zip_extract_{model_id}"
    os.makedirs(temp_dir, exist_ok=True)

    with zipfile.ZipFile(zip_path, 'r') as zip_file:
                    zip_file.extractall(temp_dir)

    # Find the source folder with unknown name
    source_folder_path = None
    for item in os.listdir(temp_dir):
        item_path = os.path.join(temp_dir, item)
        if os.path.isdir(item_path):
            source_folder_path = item_path
            break


    shutil.copytree(source_folder_path, local_repo_path, dirs_exist_ok=True)


    shutil.rmtree(temp_dir)     
    # Get the list of all tracked files in the repository
    tracked_files = set(repo.git.ls_files().split('\n'))

    # Iterate through the tracked files and check if they exist in the current directory
    for file in tracked_files:
        file_path = os.path.join(local_repo_path, file)

        # Check if the file exists in the current directory
        if not os.path.exists(file_path):
            # If the file doesn't exist locally, remove it from the repository
            repo.index.remove([file], working_tree=True)

    # # Commit changes
    repo.index.add('*')
    repo.index.commit('Fixed issues')

    # # Push changes to the remote repository
    origin = repo.remotes.origin
    origin.push()
# Out:
# Uploading models to github:  96%|█████████▌| 1767/1839 [00:00<00:00, 4460.22it/s]
# Error processing ID 267395: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://*****@github.com/ModelDBRepository/267395.git new_repos/267395
#   stderr: 'Cloning into 'new_repos/267395'...
# remote: Repository not found.
# fatal: repository 'https://github.com/ModelDBRepository/267395.git/' not found
# '
# Error processing ID 267510: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://*****@github.com/ModelDBRepository/267510.git new_repos/267510
#   stderr: 'Cloning into 'new_repos/267510'...
# remote: Repository not found.
# fatal: repository 'https://github.com/ModelDBRepository/267510.git/' not found
# '
# Error processing ID 267531: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://*****@github.com/ModelDBRepository/267531.git new_repos/267531
#   stderr: 'Cloning into 'new_repos/267531'...
# remote: Repository not found.
# fatal: repository 'https://github.com/ModelDBRepository/267531.git/' not found
# '
# Error processing ID 267552: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://*****@github.com/ModelDBRepository/267552.git new_repos/267552
#   stderr: 'Cloning into 'new_repos/267552'...
# remote: Repository not found.
# fatal: repository 'https://github.com/ModelDBRepository/267552.git/' not found
# '
# Error processing ID 267561: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://*****@github.com/ModelDBRepository/267561.git new_repos/267561
#   stderr: 'Cloning into 'new_repos/267561'...
# remote: Repository not found.
# fatal: repository 'https://github.com/ModelDBRepository/267561.git/' not found
# '
# Error processing ID 267562: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://*****@github.com/ModelDBRepository/267562.git new_repos/267562
#   stderr: 'Cloning into 'new_repos/267562'...
# remote: Repository not found.
# fatal: repository 'https://github.com/ModelDBRepository/267562.git/' not found
# '
# Error processing ID 267563: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://*****@github.com/ModelDBRepository/267563.git new_repos/267563
#   stderr: 'Cloning into 'new_repos/267563'...
# remote: Repository not found.
# fatal: repository 'https://github.com/ModelDBRepository/267563.git/' not found
# '
# Error processing ID 267564: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://*****@github.com/ModelDBRepository/267564.git new_repos/267564
#   stderr: 'Cloning into 'new_repos/267564'...
# remote: Repository not found.
# fatal: repository 'https://github.com/ModelDBRepository/267564.git/' not found
# '
# Error processing ID 267565: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://*****@github.com/ModelDBRepository/267565.git new_repos/267565
#   stderr: 'Cloning into 'new_repos/267565'...
# remote: Repository not found.
# fatal: repository 'https://github.com/ModelDBRepository/267565.git/' not found
# '
# Error processing ID 267566: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://*****@github.com/ModelDBRepository/267566.git new_repos/267566
#   stderr: 'Cloning into 'new_repos/267566'...
# remote: Repository not found.
# fatal: repository 'https://github.com/ModelDBRepository/267566.git/' not found
# '
# Error processing ID 267586: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://*****@github.com/ModelDBRepository/267586.git new_repos/267586
#   stderr: 'Cloning into 'new_repos/267586'...
# remote: Repository not found.
# fatal: repository 'https://github.com/ModelDBRepository/267586.git/' not found
# '
# Uploading models to github:  97%|█████████▋| 1787/1839 [00:47<00:02, 25.49it/s]
# Error processing ID 267611: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://*****@github.com/ModelDBRepository/267611.git new_repos/267611
#   stderr: 'Cloning into 'new_repos/267611'...
# remote: Repository not found.
# fatal: repository 'https://github.com/ModelDBRepository/267611.git/' not found
# '
# Error processing ID 267621: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://*****@github.com/ModelDBRepository/267621.git new_repos/267621
#   stderr: 'Cloning into 'new_repos/267621'...
# remote: Repository not found.
# fatal: repository 'https://github.com/ModelDBRepository/267621.git/' not found
# '
# Error processing ID 267669: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://*****@github.com/ModelDBRepository/267669.git new_repos/267669
#   stderr: 'Cloning into 'new_repos/267669'...
# remote: Repository not found.
# fatal: repository 'https://github.com/ModelDBRepository/267669.git/' not found
# '
# Error processing ID 267680: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://*****@github.com/ModelDBRepository/267680.git new_repos/267680
#   stderr: 'Cloning into 'new_repos/267680'...
# remote: Repository not found.
# fatal: repository 'https://github.com/ModelDBRepository/267680.git/' not found
# '
# Error processing ID 267682: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://*****@github.com/ModelDBRepository/267682.git new_repos/267682
#   stderr: 'Cloning into 'new_repos/267682'...
# remote: Repository not found.
# fatal: repository 'https://github.com/ModelDBRepository/267682.git/' not found
# '
# Uploading models to github:  98%|█████████▊| 1802/1839 [01:35<00:04,  8.70it/s]
# Error processing ID 267695: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://*****@github.com/ModelDBRepository/267695.git new_repos/267695
#   stderr: 'Cloning into 'new_repos/267695'...
# remote: Repository not found.
# fatal: repository 'https://github.com/ModelDBRepository/267695.git/' not found
# '
# Error processing ID 267696: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://*****@github.com/ModelDBRepository/267696.git new_repos/267696
#   stderr: 'Cloning into 'new_repos/267696'...
# remote: Repository not found.
# fatal: repository 'https://github.com/ModelDBRepository/267696.git/' not found
# '
# Error processing ID 267589: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://*****@github.com/ModelDBRepository/267589.git new_repos/267589
#   stderr: 'Cloning into 'new_repos/267589'...
# remote: Repository not found.
# fatal: repository 'https://github.com/ModelDBRepository/267589.git/' not found
# '
# Error processing ID 267596: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://*****@github.com/ModelDBRepository/267596.git new_repos/267596
#   stderr: 'Cloning into 'new_repos/267596'...
# remote: Repository not found.
# fatal: repository 'https://github.com/ModelDBRepository/267596.git/' not found
# '
# Uploading models to github: 100%|██████████| 1839/1839 [01:58<00:00, 15.56it/s]
# Error processing ID 267768: Cmd('git') failed due to: exit code(128)
#   cmdline: git clone -v -- https://*****@github.com/ModelDBRepository/267768.git new_repos/267768
#   stderr: 'Cloning into 'new_repos/267768'...
# remote: Repository not found.
# fatal: repository 'https://github.com/ModelDBRepository/267768.git/' not found
# '

# %% [markdown]
# Notes:
# This week:
# Uploaded cleaned zip files to github. These zip files were obtained from the modeldb api, I automatically removed bad files and folders such as macosx and x86_64 and combined top level folders. Then, I cloned the github repositories, copied the contents of the cleaned zip folders and removed the files/folders that were no longer there, and committed and pushed to github.
# Fixed some of the readme issues?
#
# Next week:
# Not all of the cleaned zip files have github repositories and it looks like some of the github repositories that do exist are not completely updated.
# Do we want to make a github page for the models that don't have them and then refresh all of the github repositories with the files from the modeldb page?
# New python package for git can be used to add tags so we can do that next week.

# %%
import requests
from tqdm import tqdm

# Define the ModelDB API endpoint
modeldb_api_url = "https://modeldb.science/api/v1/models"

# Make an API request to get the list of ModelDB entries
response = requests.get(modeldb_api_url)
modeldb_entries = response.json()

# Define a list to store ModelDB entries that do not match with GitHub repositories
entries_not_matching = []

# Create a tqdm progress bar
with tqdm(total=len(modeldb_entries), desc="Checking GitHub Repositories") as pbar:
    # Iterate through ModelDB entries
    for model_id in modeldb_entries:
        # Construct the GitHub repository URL based on your naming convention
        github_repo_url = f"https://github.com/ModelDBRepository/{model_id}"

        # You can use a library like PyGitHub to check if the GitHub repository exists
        # For simplicity, we will use a simple HTTP request here
        github_response = requests.head(github_repo_url)

        # Check if the GitHub repository exists (HTTP status code 200)
        if github_response.status_code != 200:
            # If it doesn't exist, add the ModelDB entry to the list
            entries_not_matching.append(model_id)

        # Update the progress bar
        pbar.update(1)

# Print the list of ModelDB entries that do not match with GitHub repositories
print("ModelDB entries without matching GitHub repositories:")
for model_id in entries_not_matching:
    print(model_id)
# Out:
# Checking GitHub Repositories: 100%|██████████| 1842/1842 [17:17<00:00,  1.78it/s]
# ModelDB entries without matching GitHub repositories:
# 7485
# 18871
# 50219
# 50392
# 50656
# 53457
# 53572
# 55273
# 55748
# 55756
# 55859
# 64167
# 64170
# 64242
# 64266
# 76883
# 82385
# 82392
# 82394
# 83512
# 83514
# 83516
# 83517
# 84627
# 84641
# 84649
# 87450
# 87751
# 87760
# 91893
# 91898
# 91899
# 93315
# 112348
# 112914
# 112922
# 113426
# 114365
# 114643
# 115968
# 116053
# 116084
# 116312
# 116313
# 117351
# 117810
# 118020
# 118195
# 118524
# 118759
# 118797
# 118799
# 118894
# 119153
# 119214
# 120115
# 120227
# 120320
# 120521
# 121628
# 125649
# 125676
# 125855
# 126052
# 126096
# 126371
# 126389
# 126392
# 126489
# 126598
# 126636
# 127192
# 127305
# 127321
# 127351
# 127967
# 127996
# 138421
# 138631
# 138634
# 139457
# 140246
# 140964
# 141835
# 142062
# 143446
# 143602
# 144387
# 144518
# 145882
# 147185
# 147487
# 147740
# 147938
# 149737
# 150635
# 151549
# 152625
# 153351
# 153452
# 154192
# 154769
# 154871
# 154927
# 154955
# 155157
# 156162
# 156470
# 169278
# 180372
# 182373
# 183017
# 183251
# 185875
# 188543
# 188552
# 190610
# 195626
# 195659
# 195731
# 195856
# 206227
# 206256
# 206356
# 218015
# 223648
# 223890
# 224843
# 224998
# 225428
# 225552
# 225583
# 226432
# 227114
# 227677
# 227978
# 228373
# 229580
# 230046
# 230578
# 230929
# 232074
# 232094
# 236439
# 236446
# 237160
# 237323
# 237326
# 237348
# 237555
# 237685
# 238347
# 238449
# 238920
# 238985
# 239103
# 239161
# 239388
# 239413
# 239418
# 240954
# 243212
# 244202
# 245805
# 246837
# 247179
# 247191
# 247196
# 247209
# 247646
# 247648
# 247655
# 247656
# 247657
# 247664
# 247696
# 247698
# 247702
# 247707
# 247709
# 247711
# 247713
# 247719
# 247848
# 253624
# 256028
# 256370
# 257965
# 258478
# 258631
# 260596
# 260740
# 261435
# 262045
# 262138
# 262356
# 262368
# 262452
# 262464
# 263571
# 263637
# 263718
# 263719
# 263961
# 263995
# 264177
# 264842
# 264844
# 265511
# 265528
# 265540
# 265591
# 265592
# 266415
# 266488
# 266492
# 266497
# 266506
# 266518
# 266524
# 266526
# 266534
# 266551
# 266552
# 266560
# 266577
# 266584
# 266609
# 266636
# 266637
# 266657
# 266663
# 266718
# 266720
# 266794
# 266796
# 266798
# 266800
# 266807
# 266819
# 266836
# 266837
# 266839
# 266840
# 266841
# 266849
# 266863
# 266868
# 266880
# 266895
# 266902
# 266910
# 266928
# 266929
# 266933
# 266941
# 266948
# 266954
# 266961
# 266974
# 266980
# 267010
# 267023
# 267026
# 267027
# 267033
# 267035
# 267039
# 267046
# 267047
# 267048
# 267049
# 267073
# 267086
# 267093
# 267116
# 267120
# 267128
# 267132
# 267139
# 267145
# 267157
# 267165
# 267173
# 267174
# 267183
# 267219
# 267221
# 267222
# 267250
# 267253
# 267280
# 267286
# 267295
# 267297
# 267309
# 267310
# 267318
# 267324
# 267329
# 267334
# 267338
# 267339
# 267357
# 267363
# 267382
# 267395
# 267510
# 267531
# 267550
# 267551
# 267552
# 267561
# 267562
# 267563
# 267564
# 267565
# 267566
# 267583
# 267586
# 267611
# 267619
# 267621
# 267647
# 267669
# 267680
# 267682
# 267686
# 267695
# 267696
# 267728
# 267589
# 267596
# 2014817
# 267768
# 2015414
# 2014996
# 2015413
# 2015412
# 2014998
# 2014833
# 267613

# %%
import requests
from tqdm import tqdm

# Define the ModelDB API endpoint
modeldb_api_url = "https://modeldb.science/api/v1/models"

# Make an API request to get the list of ModelDB entries
response = requests.get(modeldb_api_url)
modeldb_entries = response.json()

# Define a list to store ModelDB entries that do not match with GitHub repositories
entries_not_matching = []

# Create a tqdm progress bar
with tqdm(total=len(modeldb_entries), desc="Checking GitHub Repositories") as pbar:
    # Iterate through ModelDB entries
    for model_id in modeldb_entries:
        # Construct the GitHub repository URL based on your naming convention
        github_repo_url = f"https://github.com/ModelDBRepository/{model_id}"

        # You can use a library like PyGitHub to check if the GitHub repository exists
        # For simplicity, we will use a simple HTTP request here
        github_response = requests.head(github_repo_url)

        # Check if the GitHub repository exists (HTTP status code 200)
        if github_response.status_code != 200:
            # If it doesn't exist, add the ModelDB entry to the list
            entries_not_matching.append(model_id)
            
        # Update the progress bar
        pbar.update(1)

# Print the total count of ModelDB entries that do not match with GitHub repositories
print(f"Total ModelDB entries without matching GitHub repositories: {len(entries_not_matching)}")
    
# Print the list of ModelDB entries that do not have a GitHub repository
print("ModelDB entries without GitHub repositories:")
for model_id in entries_not_matching:
    print(model_id)
# Out:
# Checking GitHub Repositories: 100%|██████████| 1842/1842 [16:41<00:00,  1.84it/s]
# Total ModelDB entries without matching GitHub repositories: 342
# ModelDB entries without GitHub repositories:
# 7485
# 18871
# 50219
# 50392
# 50656
# 53457
# 53572
# 55273
# 55748
# 55756
# 55859
# 64167
# 64170
# 64242
# 64266
# 76883
# 82385
# 82392
# 82394
# 83512
# 83514
# 83516
# 83517
# 84627
# 84641
# 84649
# 87450
# 87751
# 87760
# 91893
# 91898
# 91899
# 93315
# 112348
# 112914
# 112922
# 113426
# 114365
# 114643
# 115968
# 116053
# 116084
# 116312
# 116313
# 117351
# 117810
# 118020
# 118195
# 118524
# 118759
# 118797
# 118799
# 118894
# 119153
# 119214
# 120115
# 120227
# 120320
# 120521
# 121628
# 125649
# 125676
# 125855
# 126052
# 126096
# 126371
# 126389
# 126392
# 126489
# 126598
# 126636
# 127192
# 127305
# 127321
# 127351
# 127967
# 127996
# 138421
# 138631
# 138634
# 139457
# 140246
# 140964
# 141835
# 142062
# 143446
# 143602
# 144387
# 144518
# 145882
# 147185
# 147487
# 147740
# 147938
# 149737
# 150635
# 151549
# 152625
# 153351
# 153452
# 154192
# 154769
# 154871
# 154927
# 154955
# 155157
# 156162
# 156470
# 169278
# 180372
# 182373
# 183017
# 183251
# 185875
# 188543
# 188552
# 190610
# 195626
# 195659
# 195731
# 195856
# 206227
# 206256
# 206356
# 218015
# 223648
# 223890
# 224843
# 224998
# 225428
# 225552
# 225583
# 226432
# 227114
# 227677
# 227978
# 228373
# 229580
# 230046
# 230578
# 230929
# 232074
# 232094
# 236439
# 236446
# 237160
# 237323
# 237326
# 237348
# 237555
# 237685
# 238347
# 238449
# 238920
# 238985
# 239103
# 239161
# 239388
# 239413
# 239418
# 240954
# 243212
# 244202
# 245805
# 246837
# 247179
# 247191
# 247196
# 247209
# 247646
# 247648
# 247655
# 247656
# 247657
# 247664
# 247696
# 247698
# 247702
# 247707
# 247709
# 247711
# 247713
# 247719
# 247848
# 253624
# 256028
# 256370
# 257965
# 258478
# 258631
# 260596
# 260740
# 261435
# 262045
# 262138
# 262356
# 262368
# 262452
# 262464
# 263571
# 263637
# 263718
# 263719
# 263961
# 263995
# 264177
# 264842
# 264844
# 265511
# 265528
# 265540
# 265591
# 265592
# 266415
# 266488
# 266492
# 266497
# 266506
# 266518
# 266524
# 266526
# 266534
# 266551
# 266552
# 266560
# 266577
# 266584
# 266609
# 266636
# 266637
# 266657
# 266663
# 266718
# 266720
# 266794
# 266796
# 266798
# 266800
# 266807
# 266819
# 266836
# 266837
# 266839
# 266840
# 266841
# 266849
# 266863
# 266868
# 266880
# 266895
# 266902
# 266910
# 266928
# 266929
# 266933
# 266941
# 266948
# 266954
# 266961
# 266974
# 266980
# 267010
# 267023
# 267026
# 267027
# 267033
# 267035
# 267039
# 267046
# 267047
# 267048
# 267049
# 267073
# 267086
# 267093
# 267116
# 267120
# 267128
# 267132
# 267139
# 267145
# 267157
# 267165
# 267173
# 267174
# 267183
# 267219
# 267221
# 267222
# 267250
# 267253
# 267280
# 267286
# 267295
# 267297
# 267309
# 267310
# 267318
# 267324
# 267329
# 267334
# 267338
# 267339
# 267357
# 267363
# 267382
# 267395
# 267510
# 267531
# 267550
# 267551
# 267552
# 267561
# 267562
# 267563
# 267564
# 267565
# 267566
# 267583
# 267586
# 267611
# 267619
# 267621
# 267647
# 267669
# 267680
# 267682
# 267686
# 267695
# 267696
# 267728
# 267589
# 267596
# 2014817
# 267768
# 2015414
# 2014996
# 2015413
# 2015412
# 2014998
# 2014833
# 267613

# %%
import requests
import os
import zipfile
import shutil
from git import Repo
from tqdm import tqdm

def get_file_sizes(directory):
    file_sizes = {}
    for root, dirs, files in os.walk(directory):
        for file in files:
            path = os.path.join(root, file)
            size = os.path.getsize(path)
            file_sizes[path.replace(directory, '')] = size
    return file_sizes

def compare_files(zip_file_sizes, git_file_sizes):
    for file, size in zip_file_sizes.items():
        if file not in git_file_sizes or size != git_file_sizes[file]:
            return False
    for file in git_file_sizes:
        if file not in zip_file_sizes:
            return False
    return True

# Define the ModelDB API endpoint
modeldb_api_url = "https://modeldb.science/api/v1/models"

# Make an API request to get the list of ModelDB entries
response = requests.get(modeldb_api_url)
modeldb_entries = response.json()

non_matching_models = []

with tqdm(total=len(modeldb_entries), desc="Processing Models") as pbar:
    for model_id in modeldb_entries:
        zip_path = f"zip_files/{model_id}.zip"

        # Check if ZIP file exists
        if not os.path.exists(zip_path):
            print(f"ZIP file for model {model_id} does not exist.")
            pbar.update(1)
            continue

        # Extract ZIP file
        temp_zip_dir = f"temp_zip_{model_id}"
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall(temp_zip_dir)

        # List files and sizes from ZIP
        zip_file_sizes = get_file_sizes(temp_zip_dir)

        # Clone GitHub repo
        git_repo_dir = f"git_repos/{model_id}"
        repo_url = f"https://github.com/ModelDBRepository/{model_id}.git"
        try:
            repo = Repo.clone_from(repo_url, git_repo_dir)
        except Exception as e:
            print(f"Error cloning GitHub repo for model {model_id}: {str(e)}")
            shutil.rmtree(temp_zip_dir)
            pbar.update(1)
            continue

        git_file_sizes = get_file_sizes(git_repo_dir)

        # Compare files and collect non-matching models
        if not compare_files(zip_file_sizes, git_file_sizes):
            non_matching_models.append(model_id)

        # Cleanup
        shutil.rmtree(temp_zip_dir)
        shutil.rmtree(git_repo_dir)

        # Update progress bar
        pbar.update(1)

# Print non-matching models
print("Models with non-matching ZIP files and GitHub repositories:")
for model in non_matching_models:
    print(model)
# Out:
# Processing Models: 100%|█████████████████| 1843/1843 [00:00<00:00, 12203.47it/s]
# ZIP file for model 279 does not exist.
# ZIP file for model 2487 does not exist.
# ZIP file for model 2488 does not exist.
# ZIP file for model 2730 does not exist.
# ZIP file for model 2733 does not exist.
# ZIP file for model 2796 does not exist.
# ZIP file for model 2798 does not exist.
# ZIP file for model 2937 does not exist.
# ZIP file for model 3167 does not exist.
# ZIP file for model 3263 does not exist.
# ZIP file for model 3264 does not exist.
# ZIP file for model 3289 does not exist.
# ZIP file for model 3332 does not exist.
# ZIP file for model 3342 does not exist.
# ZIP file for model 3343 does not exist.
# ZIP file for model 3344 does not exist.
# ZIP file for model 3434 does not exist.
# ZIP file for model 3454 does not exist.
# ZIP file for model 3457 does not exist.
# ZIP file for model 3483 does not exist.
# ZIP file for model 3488 does not exist.
# ZIP file for model 3491 does not exist.
# ZIP file for model 3493 does not exist.
# ZIP file for model 3507 does not exist.
# ZIP file for model 3509 does not exist.
# ZIP file for model 3511 does not exist.
# ZIP file for model 3533 does not exist.
# ZIP file for model 3648 does not exist.
# ZIP file for model 3658 does not exist.
# ZIP file for model 3660 does not exist.
# ZIP file for model 3665 does not exist.
# ZIP file for model 3670 does not exist.
# ZIP file for model 3673 does not exist.
# ZIP file for model 3676 does not exist.
# ZIP file for model 3677 does not exist.
# ZIP file for model 3682 does not exist.
# ZIP file for model 3684 does not exist.
# ZIP file for model 3785 does not exist.
# ZIP file for model 3793 does not exist.
# ZIP file for model 3798 does not exist.
# ZIP file for model 3800 does not exist.
# ZIP file for model 3801 does not exist.
# ZIP file for model 3802 does not exist.
# ZIP file for model 3805 does not exist.
# ZIP file for model 3807 does not exist.
# ZIP file for model 3808 does not exist.
# ZIP file for model 3810 does not exist.
# ZIP file for model 3812 does not exist.
# ZIP file for model 3815 does not exist.
# ZIP file for model 3817 does not exist.
# ZIP file for model 5426 does not exist.
# ZIP file for model 6763 does not exist.
# ZIP file for model 7176 does not exist.
# ZIP file for model 7386 does not exist.
# ZIP file for model 7399 does not exist.
# ZIP file for model 7400 does not exist.
# ZIP file for model 7485 does not exist.
# ZIP file for model 7509 does not exist.
# ZIP file for model 7659 does not exist.
# ZIP file for model 7907 does not exist.
# ZIP file for model 7988 does not exist.
# ZIP file for model 8115 does not exist.
# ZIP file for model 8210 does not exist.
# ZIP file for model 8284 does not exist.
# ZIP file for model 9769 does not exist.
# ZIP file for model 9848 does not exist.
# ZIP file for model 9849 does not exist.
# ZIP file for model 9851 does not exist.
# ZIP file for model 9852 does not exist.
# ZIP file for model 9853 does not exist.
# ZIP file for model 9888 does not exist.
# ZIP file for model 9889 does not exist.
# ZIP file for model 10360 does not exist.
# ZIP file for model 12631 does not exist.
# ZIP file for model 17663 does not exist.
# ZIP file for model 17664 does not exist.
# ZIP file for model 18197 does not exist.
# ZIP file for model 18198 does not exist.
# ZIP file for model 18500 does not exist.
# ZIP file for model 18501 does not exist.
# ZIP file for model 18502 does not exist.
# ZIP file for model 18738 does not exist.
# ZIP file for model 18742 does not exist.
# ZIP file for model 18871 does not exist.
# ZIP file for model 19022 does not exist.
# ZIP file for model 19176 does not exist.
# ZIP file for model 19214 does not exist.
# ZIP file for model 19366 does not exist.
# ZIP file for model 19491 does not exist.
# ZIP file for model 19591 does not exist.
# ZIP file for model 19696 does not exist.
# ZIP file for model 19698 does not exist.
# ZIP file for model 19746 does not exist.
# ZIP file for model 19747 does not exist.
# ZIP file for model 19920 does not exist.
# ZIP file for model 20007 does not exist.
# ZIP file for model 20014 does not exist.
# ZIP file for model 20015 does not exist.
# ZIP file for model 20212 does not exist.
# ZIP file for model 20756 does not exist.
# ZIP file for model 21329 does not exist.
# ZIP file for model 21984 does not exist.
# ZIP file for model 22203 does not exist.
# ZIP file for model 26997 does not exist.
# ZIP file for model 28189 does not exist.
# ZIP file for model 28316 does not exist.
# ZIP file for model 29942 does not exist.
# ZIP file for model 32992 does not exist.
# ZIP file for model 33728 does not exist.
# ZIP file for model 33975 does not exist.
# ZIP file for model 33986 does not exist.
# ZIP file for model 34163 does not exist.
# ZIP file for model 34168 does not exist.
# ZIP file for model 34558 does not exist.
# ZIP file for model 34560 does not exist.
# ZIP file for model 34606 does not exist.
# ZIP file for model 35358 does not exist.
# ZIP file for model 35781 does not exist.
# ZIP file for model 36834 does not exist.
# ZIP file for model 36861 does not exist.
# ZIP file for model 36869 does not exist.
# ZIP file for model 36956 does not exist.
# ZIP file for model 37103 does not exist.
# ZIP file for model 37129 does not exist.
# ZIP file for model 37436 does not exist.
# ZIP file for model 37819 does not exist.
# ZIP file for model 37856 does not exist.
# ZIP file for model 37857 does not exist.
# ZIP file for model 39948 does not exist.
# ZIP file for model 39949 does not exist.
# ZIP file for model 42020 does not exist.
# ZIP file for model 42022 does not exist.
# ZIP file for model 42036 does not exist.
# ZIP file for model 42037 does not exist.
# ZIP file for model 42044 does not exist.
# ZIP file for model 42046 does not exist.
# ZIP file for model 42047 does not exist.
# ZIP file for model 42321 does not exist.
# ZIP file for model 42322 does not exist.
# ZIP file for model 42323 does not exist.
# ZIP file for model 43039 does not exist.
# ZIP file for model 44050 does not exist.
# ZIP file for model 44972 does not exist.
# ZIP file for model 45513 does not exist.
# ZIP file for model 45525 does not exist.
# ZIP file for model 45539 does not exist.
# ZIP file for model 46839 does not exist.
# ZIP file for model 48332 does not exist.
# ZIP file for model 48506 does not exist.
# ZIP file for model 49305 does not exist.
# ZIP file for model 50207 does not exist.
# ZIP file for model 50210 does not exist.
# ZIP file for model 50219 does not exist.
# ZIP file for model 50391 does not exist.
# ZIP file for model 50392 does not exist.
# ZIP file for model 50656 does not exist.
# ZIP file for model 50997 does not exist.
# ZIP file for model 51022 does not exist.
# ZIP file for model 51196 does not exist.
# ZIP file for model 51781 does not exist.
# ZIP file for model 52034 does not exist.
# ZIP file for model 53425 does not exist.
# ZIP file for model 53427 does not exist.
# ZIP file for model 53435 does not exist.
# ZIP file for model 53437 does not exist.
# ZIP file for model 53451 does not exist.
# ZIP file for model 53457 does not exist.
# ZIP file for model 53559 does not exist.
# ZIP file for model 53569 does not exist.
# ZIP file for model 53572 does not exist.
# ZIP file for model 53869 does not exist.
# ZIP file for model 53876 does not exist.
# ZIP file for model 53893 does not exist.
# ZIP file for model 53894 does not exist.
# ZIP file for model 53965 does not exist.
# ZIP file for model 54141 does not exist.
# ZIP file for model 54154 does not exist.
# ZIP file for model 54896 does not exist.
# ZIP file for model 54903 does not exist.
# ZIP file for model 55035 does not exist.
# ZIP file for model 55273 does not exist.
# ZIP file for model 55748 does not exist.
# ZIP file for model 55749 does not exist.
# ZIP file for model 55756 does not exist.
# ZIP file for model 55859 does not exist.
# ZIP file for model 56012 does not exist.
# ZIP file for model 57905 does not exist.
# ZIP file for model 57910 does not exist.
# ZIP file for model 58172 does not exist.
# ZIP file for model 58195 does not exist.
# ZIP file for model 58199 does not exist.
# ZIP file for model 58581 does not exist.
# ZIP file for model 58582 does not exist.
# ZIP file for model 58957 does not exist.
# ZIP file for model 59479 does not exist.
# ZIP file for model 59480 does not exist.
# ZIP file for model 59581 does not exist.
# ZIP file for model 59582 does not exist.
# ZIP file for model 62266 does not exist.
# ZIP file for model 62268 does not exist.
# ZIP file for model 62272 does not exist.
# ZIP file for model 62284 does not exist.
# ZIP file for model 62285 does not exist.
# ZIP file for model 62286 does not exist.
# ZIP file for model 62287 does not exist.
# ZIP file for model 62654 does not exist.
# ZIP file for model 62661 does not exist.
# ZIP file for model 62673 does not exist.
# ZIP file for model 62676 does not exist.
# ZIP file for model 64167 does not exist.
# ZIP file for model 64170 does not exist.
# ZIP file for model 64171 does not exist.
# ZIP file for model 64195 does not exist.
# ZIP file for model 64212 does not exist.
# ZIP file for model 64216 does not exist.
# ZIP file for model 64228 does not exist.
# ZIP file for model 64229 does not exist.
# ZIP file for model 64242 does not exist.
# ZIP file for model 64255 does not exist.
# ZIP file for model 64259 does not exist.
# ZIP file for model 64261 does not exist.
# ZIP file for model 64266 does not exist.
# ZIP file for model 64285 does not exist.
# ZIP file for model 64296 does not exist.
# ZIP file for model 65412 does not exist.
# ZIP file for model 66268 does not exist.
# ZIP file for model 71312 does not exist.
# ZIP file for model 71317 does not exist.
# ZIP file for model 74298 does not exist.
# ZIP file for model 76879 does not exist.
# ZIP file for model 76883 does not exist.
# ZIP file for model 79145 does not exist.
# ZIP file for model 79237 does not exist.
# ZIP file for model 79238 does not exist.
# ZIP file for model 79461 does not exist.
# ZIP file for model 79465 does not exist.
# ZIP file for model 79471 does not exist.
# ZIP file for model 79488 does not exist.
# ZIP file for model 80769 does not exist.
# ZIP file for model 82364 does not exist.
# ZIP file for model 82385 does not exist.
# ZIP file for model 82392 does not exist.
# ZIP file for model 82394 does not exist.
# ZIP file for model 82758 does not exist.
# ZIP file for model 82784 does not exist.
# ZIP file for model 82849 does not exist.
# ZIP file for model 82891 does not exist.
# ZIP file for model 83319 does not exist.
# ZIP file for model 83320 does not exist.
# ZIP file for model 83344 does not exist.
# ZIP file for model 83472 does not exist.
# ZIP file for model 83491 does not exist.
# ZIP file for model 83508 does not exist.
# ZIP file for model 83512 does not exist.
# ZIP file for model 83514 does not exist.
# ZIP file for model 83516 does not exist.
# ZIP file for model 83517 does not exist.
# ZIP file for model 83520 does not exist.
# ZIP file for model 83521 does not exist.
# ZIP file for model 83523 does not exist.
# ZIP file for model 83528 does not exist.
# ZIP file for model 83547 does not exist.
# ZIP file for model 83558 does not exist.
# ZIP file for model 83559 does not exist.
# ZIP file for model 83560 does not exist.
# ZIP file for model 83562 does not exist.
# ZIP file for model 83570 does not exist.
# ZIP file for model 83575 does not exist.
# ZIP file for model 83590 does not exist.
# ZIP file for model 84167 does not exist.
# ZIP file for model 84589 does not exist.
# ZIP file for model 84593 does not exist.
# ZIP file for model 84599 does not exist.
# ZIP file for model 84606 does not exist.
# ZIP file for model 84612 does not exist.
# ZIP file for model 84627 does not exist.
# ZIP file for model 84641 does not exist.
# ZIP file for model 84649 does not exist.
# ZIP file for model 84655 does not exist.
# ZIP file for model 85112 does not exist.
# ZIP file for model 85981 does not exist.
# ZIP file for model 86537 does not exist.
# ZIP file for model 86538 does not exist.
# ZIP file for model 87216 does not exist.
# ZIP file for model 87278 does not exist.
# ZIP file for model 87284 does not exist.
# ZIP file for model 87450 does not exist.
# ZIP file for model 87454 does not exist.
# ZIP file for model 87473 does not exist.
# ZIP file for model 87535 does not exist.
# ZIP file for model 87546 does not exist.
# ZIP file for model 87581 does not exist.
# ZIP file for model 87582 does not exist.
# ZIP file for model 87585 does not exist.
# ZIP file for model 87751 does not exist.
# ZIP file for model 87760 does not exist.
# ZIP file for model 87762 does not exist.
# ZIP file for model 91387 does not exist.
# ZIP file for model 91893 does not exist.
# ZIP file for model 91898 does not exist.
# ZIP file for model 91899 does not exist.
# ZIP file for model 93315 does not exist.
# ZIP file for model 93319 does not exist.
# ZIP file for model 93321 does not exist.
# ZIP file for model 93325 does not exist.
# ZIP file for model 93326 does not exist.
# ZIP file for model 93349 does not exist.
# ZIP file for model 93390 does not exist.
# ZIP file for model 93394 does not exist.
# ZIP file for model 93398 does not exist.
# ZIP file for model 93416 does not exist.
# ZIP file for model 93422 does not exist.
# ZIP file for model 93449 does not exist.
# ZIP file for model 94321 does not exist.
# ZIP file for model 94845 does not exist.
# ZIP file for model 95870 does not exist.
# ZIP file for model 95960 does not exist.
# ZIP file for model 95990 does not exist.
# ZIP file for model 96444 does not exist.
# ZIP file for model 97263 does not exist.
# ZIP file for model 97274 does not exist.
# ZIP file for model 97743 does not exist.
# ZIP file for model 97747 does not exist.
# ZIP file for model 97756 does not exist.
# ZIP file for model 97850 does not exist.
# ZIP file for model 97860 does not exist.
# ZIP file for model 97863 does not exist.
# ZIP file for model 97868 does not exist.
# ZIP file for model 97874 does not exist.
# ZIP file for model 97903 does not exist.
# ZIP file for model 97917 does not exist.
# ZIP file for model 97972 does not exist.
# ZIP file for model 97983 does not exist.
# ZIP file for model 97985 does not exist.
# ZIP file for model 98003 does not exist.
# ZIP file for model 98005 does not exist.
# ZIP file for model 98017 does not exist.
# ZIP file for model 98902 does not exist.
# ZIP file for model 100603 does not exist.
# ZIP file for model 101629 does not exist.
# ZIP file for model 102279 does not exist.
# ZIP file for model 102288 does not exist.
# ZIP file for model 102871 does not exist.
# ZIP file for model 104623 does not exist.
# ZIP file for model 105383 does not exist.
# ZIP file for model 105385 does not exist.
# ZIP file for model 105501 does not exist.
# ZIP file for model 105506 does not exist.
# ZIP file for model 105507 does not exist.
# ZIP file for model 105528 does not exist.
# ZIP file for model 106551 does not exist.
# ZIP file for model 106891 does not exist.
# ZIP file for model 108458 does not exist.
# ZIP file for model 108459 does not exist.
# ZIP file for model 110022 does not exist.
# ZIP file for model 110560 does not exist.
# ZIP file for model 111870 does not exist.
# ZIP file for model 111877 does not exist.
# ZIP file for model 111880 does not exist.
# ZIP file for model 111967 does not exist.
# ZIP file for model 112079 does not exist.
# ZIP file for model 112086 does not exist.
# ZIP file for model 112348 does not exist.
# ZIP file for model 112359 does not exist.
# ZIP file for model 112468 does not exist.
# ZIP file for model 112546 does not exist.
# ZIP file for model 112547 does not exist.
# ZIP file for model 112633 does not exist.
# ZIP file for model 112685 does not exist.
# ZIP file for model 112834 does not exist.
# ZIP file for model 112836 does not exist.
# ZIP file for model 112914 does not exist.
# ZIP file for model 112922 does not exist.
# ZIP file for model 112968 does not exist.
# ZIP file for model 113426 does not exist.
# ZIP file for model 113446 does not exist.
# ZIP file for model 113459 does not exist.
# ZIP file for model 113649 does not exist.
# ZIP file for model 113732 does not exist.
# ZIP file for model 113939 does not exist.
# ZIP file for model 113949 does not exist.
# ZIP file for model 113997 does not exist.
# ZIP file for model 114047 does not exist.
# ZIP file for model 114108 does not exist.
# ZIP file for model 114230 does not exist.
# ZIP file for model 114242 does not exist.
# ZIP file for model 114310 does not exist.
# ZIP file for model 114337 does not exist.
# ZIP file for model 114342 does not exist.
# ZIP file for model 114355 does not exist.
# ZIP file for model 114359 does not exist.
# ZIP file for model 114365 does not exist.
# ZIP file for model 114394 does not exist.
# ZIP file for model 114424 does not exist.
# ZIP file for model 114450 does not exist.
# ZIP file for model 114451 does not exist.
# ZIP file for model 114452 does not exist.
# ZIP file for model 114637 does not exist.
# ZIP file for model 114639 does not exist.
# ZIP file for model 114643 does not exist.
# ZIP file for model 114654 does not exist.
# ZIP file for model 114655 does not exist.
# ZIP file for model 114665 does not exist.
# ZIP file for model 114685 does not exist.
# ZIP file for model 114735 does not exist.
# ZIP file for model 115356 does not exist.
# ZIP file for model 115357 does not exist.
# ZIP file for model 115813 does not exist.
# ZIP file for model 115966 does not exist.
# ZIP file for model 115968 does not exist.
# ZIP file for model 116053 does not exist.
# ZIP file for model 116084 does not exist.
# ZIP file for model 116086 does not exist.
# ZIP file for model 116094 does not exist.
# ZIP file for model 116096 does not exist.
# ZIP file for model 116123 does not exist.
# ZIP file for model 116312 does not exist.
# ZIP file for model 116313 does not exist.
# ZIP file for model 116386 does not exist.
# ZIP file for model 116491 does not exist.
# ZIP file for model 116567 does not exist.
# ZIP file for model 116575 does not exist.
# ZIP file for model 116606 does not exist.
# ZIP file for model 116740 does not exist.
# ZIP file for model 116769 does not exist.
# ZIP file for model 116806 does not exist.
# ZIP file for model 116830 does not exist.
# ZIP file for model 116835 does not exist.
# ZIP file for model 116837 does not exist.
# ZIP file for model 116838 does not exist.
# ZIP file for model 116862 does not exist.
# ZIP file for model 116867 does not exist.
# ZIP file for model 116870 does not exist.
# ZIP file for model 116871 does not exist.
# ZIP file for model 116901 does not exist.
# ZIP file for model 116945 does not exist.
# ZIP file for model 116956 does not exist.
# ZIP file for model 116957 does not exist.
# ZIP file for model 116981 does not exist.
# ZIP file for model 116983 does not exist.
# ZIP file for model 117204 does not exist.
# ZIP file for model 117207 does not exist.
# ZIP file for model 117330 does not exist.
# ZIP file for model 117351 does not exist.
# ZIP file for model 117361 does not exist.
# ZIP file for model 117459 does not exist.
# ZIP file for model 117508 does not exist.
# ZIP file for model 117514 does not exist.
# ZIP file for model 117691 does not exist.
# ZIP file for model 117810 does not exist.
# ZIP file for model 117966 does not exist.
# ZIP file for model 118014 does not exist.
# ZIP file for model 118020 does not exist.
# ZIP file for model 118092 does not exist.
# ZIP file for model 118098 does not exist.
# ZIP file for model 118195 does not exist.
# ZIP file for model 118199 does not exist.
# ZIP file for model 118261 does not exist.
# ZIP file for model 118326 does not exist.
# ZIP file for model 118389 does not exist.
# ZIP file for model 118392 does not exist.
# ZIP file for model 118434 does not exist.
# ZIP file for model 118524 does not exist.
# ZIP file for model 118554 does not exist.
# ZIP file for model 118631 does not exist.
# ZIP file for model 118662 does not exist.
# ZIP file for model 118759 does not exist.
# ZIP file for model 118797 does not exist.
# ZIP file for model 118799 does not exist.
# ZIP file for model 118894 does not exist.
# ZIP file for model 118986 does not exist.
# ZIP file for model 119153 does not exist.
# ZIP file for model 119159 does not exist.
# ZIP file for model 119214 does not exist.
# ZIP file for model 119266 does not exist.
# ZIP file for model 119283 does not exist.
# ZIP file for model 120115 does not exist.
# ZIP file for model 120117 does not exist.
# ZIP file for model 120137 does not exist.
# ZIP file for model 120184 does not exist.
# ZIP file for model 120227 does not exist.
# ZIP file for model 120243 does not exist.
# ZIP file for model 120246 does not exist.
# ZIP file for model 120320 does not exist.
# ZIP file for model 120521 does not exist.
# ZIP file for model 120692 does not exist.
# ZIP file for model 120783 does not exist.
# ZIP file for model 120798 does not exist.
# ZIP file for model 120835 does not exist.
# ZIP file for model 120907 does not exist.
# ZIP file for model 120910 does not exist.
# ZIP file for model 121060 does not exist.
# ZIP file for model 121253 does not exist.
# ZIP file for model 121259 does not exist.
# ZIP file for model 121600 does not exist.
# ZIP file for model 121628 does not exist.
# ZIP file for model 122329 does not exist.
# ZIP file for model 122369 does not exist.
# ZIP file for model 122442 does not exist.
# ZIP file for model 123086 does not exist.
# ZIP file for model 123453 does not exist.
# ZIP file for model 123623 does not exist.
# ZIP file for model 123815 does not exist.
# ZIP file for model 123848 does not exist.
# ZIP file for model 123897 does not exist.
# ZIP file for model 123927 does not exist.
# ZIP file for model 123928 does not exist.
# ZIP file for model 123986 does not exist.
# ZIP file for model 123987 does not exist.
# ZIP file for model 124043 does not exist.
# ZIP file for model 124063 does not exist.
# ZIP file for model 124111 does not exist.
# ZIP file for model 124291 does not exist.
# ZIP file for model 124329 does not exist.
# ZIP file for model 124392 does not exist.
# ZIP file for model 124394 does not exist.
# ZIP file for model 124513 does not exist.
# ZIP file for model 125125 does not exist.
# ZIP file for model 125152 does not exist.
# ZIP file for model 125154 does not exist.
# ZIP file for model 125290 does not exist.
# ZIP file for model 125378 does not exist.
# ZIP file for model 125385 does not exist.
# ZIP file for model 125529 does not exist.
# ZIP file for model 125649 does not exist.
# ZIP file for model 125676 does not exist.
# ZIP file for model 125683 does not exist.
# ZIP file for model 125689 does not exist.
# ZIP file for model 125733 does not exist.
# ZIP file for model 125745 does not exist.
# ZIP file for model 125748 does not exist.
# ZIP file for model 125855 does not exist.
# ZIP file for model 125857 does not exist.
# ZIP file for model 126052 does not exist.
# ZIP file for model 126096 does not exist.
# ZIP file for model 126098 does not exist.
# ZIP file for model 126371 does not exist.
# ZIP file for model 126389 does not exist.
# ZIP file for model 126392 does not exist.
# ZIP file for model 126465 does not exist.
# ZIP file for model 126466 does not exist.
# ZIP file for model 126467 does not exist.
# ZIP file for model 126471 does not exist.
# ZIP file for model 126489 does not exist.
# ZIP file for model 126598 does not exist.
# ZIP file for model 126636 does not exist.
# ZIP file for model 126637 does not exist.
# ZIP file for model 126640 does not exist.
# ZIP file for model 126776 does not exist.
# ZIP file for model 126814 does not exist.
# ZIP file for model 126899 does not exist.
# ZIP file for model 127021 does not exist.
# ZIP file for model 127022 does not exist.
# ZIP file for model 127190 does not exist.
# ZIP file for model 127192 does not exist.
# ZIP file for model 127305 does not exist.
# ZIP file for model 127321 does not exist.
# ZIP file for model 127351 does not exist.
# ZIP file for model 127355 does not exist.
# ZIP file for model 127388 does not exist.
# ZIP file for model 127507 does not exist.
# ZIP file for model 127512 does not exist.
# ZIP file for model 127728 does not exist.
# ZIP file for model 127878 does not exist.
# ZIP file for model 127887 does not exist.
# ZIP file for model 127967 does not exist.
# ZIP file for model 127992 does not exist.
# ZIP file for model 127995 does not exist.
# ZIP file for model 127996 does not exist.
# ZIP file for model 128043 does not exist.
# ZIP file for model 128068 does not exist.
# ZIP file for model 128079 does not exist.
# ZIP file for model 128446 does not exist.
# ZIP file for model 128449 does not exist.
# ZIP file for model 128502 does not exist.
# ZIP file for model 128559 does not exist.
# ZIP file for model 128812 does not exist.
# ZIP file for model 128816 does not exist.
# ZIP file for model 128818 does not exist.
# ZIP file for model 128874 does not exist.
# ZIP file for model 129067 does not exist.
# ZIP file for model 129071 does not exist.
# ZIP file for model 129149 does not exist.
# ZIP file for model 135787 does not exist.
# ZIP file for model 135838 does not exist.
# ZIP file for model 135839 does not exist.
# ZIP file for model 135898 does not exist.
# ZIP file for model 135902 does not exist.
# ZIP file for model 135903 does not exist.
# ZIP file for model 136024 does not exist.
# ZIP file for model 136026 does not exist.
# ZIP file for model 136095 does not exist.
# ZIP file for model 136097 does not exist.
# ZIP file for model 136175 does not exist.
# ZIP file for model 136176 does not exist.
# ZIP file for model 136296 does not exist.
# ZIP file for model 136308 does not exist.
# ZIP file for model 136309 does not exist.
# ZIP file for model 136310 does not exist.
# ZIP file for model 136315 does not exist.
# ZIP file for model 136380 does not exist.
# ZIP file for model 136715 does not exist.
# ZIP file for model 136717 does not exist.
# ZIP file for model 136773 does not exist.
# ZIP file for model 136799 does not exist.
# ZIP file for model 136803 does not exist.
# ZIP file for model 136807 does not exist.
# ZIP file for model 136808 does not exist.
# ZIP file for model 137259 does not exist.
# ZIP file for model 137263 does not exist.
# ZIP file for model 137502 does not exist.
# ZIP file for model 137505 does not exist.
# ZIP file for model 137676 does not exist.
# ZIP file for model 137743 does not exist.
# ZIP file for model 137745 does not exist.
# ZIP file for model 137845 does not exist.
# ZIP file for model 137846 does not exist.
# ZIP file for model 137989 does not exist.
# ZIP file for model 138082 does not exist.
# ZIP file for model 138205 does not exist.
# ZIP file for model 138273 does not exist.
# ZIP file for model 138321 does not exist.
# ZIP file for model 138379 does not exist.
# ZIP file for model 138382 does not exist.
# ZIP file for model 138421 does not exist.
# ZIP file for model 138631 does not exist.
# ZIP file for model 138634 does not exist.
# ZIP file for model 138950 does not exist.
# ZIP file for model 138951 does not exist.
# ZIP file for model 138970 does not exist.
# ZIP file for model 139150 does not exist.
# ZIP file for model 139266 does not exist.
# ZIP file for model 139296 does not exist.
# ZIP file for model 139418 does not exist.
# ZIP file for model 139421 does not exist.
# ZIP file for model 139457 does not exist.
# ZIP file for model 139653 does not exist.
# ZIP file for model 139654 does not exist.
# ZIP file for model 139655 does not exist.
# ZIP file for model 139656 does not exist.
# ZIP file for model 139657 does not exist.
# ZIP file for model 139760 does not exist.
# ZIP file for model 139883 does not exist.
# ZIP file for model 140033 does not exist.
# ZIP file for model 140038 does not exist.
# ZIP file for model 140246 does not exist.
# ZIP file for model 140249 does not exist.
# ZIP file for model 140254 does not exist.
# ZIP file for model 140299 does not exist.
# ZIP file for model 140462 does not exist.
# ZIP file for model 140465 does not exist.
# ZIP file for model 140471 does not exist.
# ZIP file for model 140599 does not exist.
# ZIP file for model 140732 does not exist.
# ZIP file for model 140788 does not exist.
# ZIP file for model 140789 does not exist.
# ZIP file for model 140828 does not exist.
# ZIP file for model 140881 does not exist.
# ZIP file for model 140964 does not exist.
# ZIP file for model 141061 does not exist.
# ZIP file for model 141062 does not exist.
# ZIP file for model 141063 does not exist.
# ZIP file for model 141192 does not exist.
# ZIP file for model 141226 does not exist.
# ZIP file for model 141270 does not exist.
# ZIP file for model 141272 does not exist.
# ZIP file for model 141273 does not exist.
# ZIP file for model 141274 does not exist.
# ZIP file for model 141505 does not exist.
# ZIP file for model 141507 does not exist.
# ZIP file for model 141699 does not exist.
# ZIP file for model 141835 does not exist.
# ZIP file for model 141991 does not exist.
# ZIP file for model 142062 does not exist.
# ZIP file for model 142104 does not exist.
# ZIP file for model 142199 does not exist.
# ZIP file for model 142273 does not exist.
# ZIP file for model 142630 does not exist.
# ZIP file for model 142990 does not exist.
# ZIP file for model 142993 does not exist.
# ZIP file for model 143072 does not exist.
# ZIP file for model 143083 does not exist.
# ZIP file for model 143100 does not exist.
# ZIP file for model 143114 does not exist.
# ZIP file for model 143148 does not exist.
# ZIP file for model 143248 does not exist.
# ZIP file for model 143253 does not exist.
# ZIP file for model 143442 does not exist.
# ZIP file for model 143446 does not exist.
# ZIP file for model 143602 does not exist.
# ZIP file for model 143604 does not exist.
# ZIP file for model 143633 does not exist.
# ZIP file for model 143635 does not exist.
# ZIP file for model 143671 does not exist.
# ZIP file for model 143719 does not exist.
# ZIP file for model 143751 does not exist.
# ZIP file for model 143753 does not exist.
# ZIP file for model 143760 does not exist.
# ZIP file for model 144006 does not exist.
# ZIP file for model 144007 does not exist.
# ZIP file for model 144010 does not exist.
# ZIP file for model 144027 does not exist.
# ZIP file for model 144054 does not exist.
# ZIP file for model 144089 does not exist.
# ZIP file for model 144096 does not exist.
# ZIP file for model 144372 does not exist.
# ZIP file for model 144376 does not exist.
# ZIP file for model 144380 does not exist.
# ZIP file for model 144385 does not exist.
# ZIP file for model 144387 does not exist.
# ZIP file for model 144392 does not exist.
# ZIP file for model 144401 does not exist.
# ZIP file for model 144403 does not exist.
# ZIP file for model 144416 does not exist.
# ZIP file for model 144450 does not exist.
# ZIP file for model 144455 does not exist.
# ZIP file for model 144463 does not exist.
# ZIP file for model 144468 does not exist.
# ZIP file for model 144477 does not exist.
# ZIP file for model 144481 does not exist.
# ZIP file for model 144482 does not exist.
# ZIP file for model 144489 does not exist.
# ZIP file for model 144490 does not exist.
# ZIP file for model 144499 does not exist.
# ZIP file for model 144502 does not exist.
# ZIP file for model 144509 does not exist.
# ZIP file for model 144511 does not exist.
# ZIP file for model 144518 does not exist.
# ZIP file for model 144520 does not exist.
# ZIP file for model 144523 does not exist.
# ZIP file for model 144526 does not exist.
# ZIP file for model 144538 does not exist.
# ZIP file for model 144541 does not exist.
# ZIP file for model 144549 does not exist.
# ZIP file for model 144553 does not exist.
# ZIP file for model 144560 does not exist.
# ZIP file for model 144566 does not exist.
# ZIP file for model 144570 does not exist.
# ZIP file for model 144572 does not exist.
# ZIP file for model 144579 does not exist.
# ZIP file for model 144586 does not exist.
# ZIP file for model 144589 does not exist.
# ZIP file for model 144590 does not exist.
# ZIP file for model 144976 does not exist.
# ZIP file for model 144993 does not exist.
# ZIP file for model 145162 does not exist.
# ZIP file for model 145672 does not exist.
# ZIP file for model 145800 does not exist.
# ZIP file for model 145801 does not exist.
# ZIP file for model 145803 does not exist.
# ZIP file for model 145836 does not exist.
# ZIP file for model 145882 does not exist.
# ZIP file for model 145917 does not exist.
# ZIP file for model 146024 does not exist.
# ZIP file for model 146026 does not exist.
# ZIP file for model 146030 does not exist.
# ZIP file for model 146050 does not exist.
# ZIP file for model 146376 does not exist.
# ZIP file for model 146499 does not exist.
# ZIP file for model 146504 does not exist.
# ZIP file for model 146509 does not exist.
# ZIP file for model 146554 does not exist.
# ZIP file for model 146565 does not exist.
# ZIP file for model 146583 does not exist.
# ZIP file for model 146734 does not exist.
# ZIP file for model 146813 does not exist.
# ZIP file for model 146949 does not exist.
# ZIP file for model 146950 does not exist.
# ZIP file for model 146953 does not exist.
# ZIP file for model 147103 does not exist.
# ZIP file for model 147117 does not exist.
# ZIP file for model 147141 does not exist.
# ZIP file for model 147172 does not exist.
# ZIP file for model 147185 does not exist.
# ZIP file for model 147218 does not exist.
# ZIP file for model 147366 does not exist.
# ZIP file for model 147367 does not exist.
# ZIP file for model 147460 does not exist.
# ZIP file for model 147461 does not exist.
# ZIP file for model 147487 does not exist.
# ZIP file for model 147514 does not exist.
# ZIP file for model 147538 does not exist.
# ZIP file for model 147539 does not exist.
# ZIP file for model 147578 does not exist.
# ZIP file for model 147740 does not exist.
# ZIP file for model 147748 does not exist.
# ZIP file for model 147756 does not exist.
# ZIP file for model 147757 does not exist.
# ZIP file for model 147867 does not exist.
# ZIP file for model 147929 does not exist.
# ZIP file for model 147938 does not exist.
# ZIP file for model 148035 does not exist.
# ZIP file for model 148094 does not exist.
# ZIP file for model 148253 does not exist.
# ZIP file for model 148320 does not exist.
# ZIP file for model 148637 does not exist.
# ZIP file for model 148644 does not exist.
# ZIP file for model 148646 does not exist.
# ZIP file for model 149000 does not exist.
# ZIP file for model 149100 does not exist.
# ZIP file for model 149162 does not exist.
# ZIP file for model 149174 does not exist.
# ZIP file for model 149175 does not exist.
# ZIP file for model 149415 does not exist.
# ZIP file for model 149737 does not exist.
# ZIP file for model 149739 does not exist.
# ZIP file for model 149910 does not exist.
# ZIP file for model 149913 does not exist.
# ZIP file for model 149914 does not exist.
# ZIP file for model 150024 does not exist.
# ZIP file for model 150031 does not exist.
# ZIP file for model 150067 does not exist.
# ZIP file for model 150206 does not exist.
# ZIP file for model 150207 does not exist.
# ZIP file for model 150211 does not exist.
# ZIP file for model 150217 does not exist.
# ZIP file for model 150225 does not exist.
# ZIP file for model 150239 does not exist.
# ZIP file for model 150240 does not exist.
# ZIP file for model 150245 does not exist.
# ZIP file for model 150284 does not exist.
# ZIP file for model 150288 does not exist.
# ZIP file for model 150437 does not exist.
# ZIP file for model 150440 does not exist.
# ZIP file for model 150445 does not exist.
# ZIP file for model 150446 does not exist.
# ZIP file for model 150538 does not exist.
# ZIP file for model 150551 does not exist.
# ZIP file for model 150556 does not exist.
# ZIP file for model 150621 does not exist.
# ZIP file for model 150622 does not exist.
# ZIP file for model 150635 does not exist.
# ZIP file for model 150678 does not exist.
# ZIP file for model 150691 does not exist.
# ZIP file for model 150697 does not exist.
# ZIP file for model 150698 does not exist.
# ZIP file for model 150804 does not exist.
# ZIP file for model 150806 does not exist.
# ZIP file for model 150846 does not exist.
# ZIP file for model 150912 does not exist.
# ZIP file for model 151126 does not exist.
# ZIP file for model 151282 does not exist.
# ZIP file for model 151338 does not exist.
# ZIP file for model 151404 does not exist.
# ZIP file for model 151443 does not exist.
# ZIP file for model 151458 does not exist.
# ZIP file for model 151460 does not exist.
# ZIP file for model 151482 does not exist.
# ZIP file for model 151483 does not exist.
# ZIP file for model 151549 does not exist.
# ZIP file for model 151677 does not exist.
# ZIP file for model 151681 does not exist.
# ZIP file for model 151685 does not exist.
# ZIP file for model 151686 does not exist.
# ZIP file for model 151692 does not exist.
# ZIP file for model 151731 does not exist.
# ZIP file for model 151817 does not exist.
# ZIP file for model 151825 does not exist.
# ZIP file for model 151945 does not exist.
# ZIP file for model 151949 does not exist.
# ZIP file for model 151951 does not exist.
# ZIP file for model 152028 does not exist.
# ZIP file for model 152111 does not exist.
# ZIP file for model 152112 does not exist.
# ZIP file for model 152113 does not exist.
# ZIP file for model 152197 does not exist.
# ZIP file for model 152200 does not exist.
# ZIP file for model 152292 does not exist.
# ZIP file for model 152539 does not exist.
# ZIP file for model 152625 does not exist.
# ZIP file for model 152636 does not exist.
# ZIP file for model 152788 does not exist.
# ZIP file for model 152897 does not exist.
# ZIP file for model 152913 does not exist.
# ZIP file for model 152966 does not exist.
# ZIP file for model 153030 does not exist.
# ZIP file for model 153092 does not exist.
# ZIP file for model 153196 does not exist.
# ZIP file for model 153280 does not exist.
# ZIP file for model 153351 does not exist.
# ZIP file for model 153355 does not exist.
# ZIP file for model 153452 does not exist.
# ZIP file for model 153573 does not exist.
# ZIP file for model 153574 does not exist.
# ZIP file for model 153633 does not exist.
# ZIP file for model 153635 does not exist.
# ZIP file for model 153660 does not exist.
# ZIP file for model 153697 does not exist.
# ZIP file for model 153740 does not exist.
# ZIP file for model 153985 does not exist.
# ZIP file for model 153988 does not exist.
# ZIP file for model 153998 does not exist.
# ZIP file for model 154096 does not exist.
# ZIP file for model 154192 does not exist.
# ZIP file for model 154198 does not exist.
# ZIP file for model 154288 does not exist.
# ZIP file for model 154293 does not exist.
# ZIP file for model 154348 does not exist.
# ZIP file for model 154732 does not exist.
# ZIP file for model 154739 does not exist.
# ZIP file for model 154769 does not exist.
# ZIP file for model 154770 does not exist.
# ZIP file for model 154871 does not exist.
# ZIP file for model 154872 does not exist.
# ZIP file for model 154927 does not exist.
# ZIP file for model 154955 does not exist.
# ZIP file for model 154967 does not exist.
# ZIP file for model 154968 does not exist.
# ZIP file for model 155057 does not exist.
# ZIP file for model 155130 does not exist.
# ZIP file for model 155131 does not exist.
# ZIP file for model 155157 does not exist.
# ZIP file for model 155565 does not exist.
# ZIP file for model 155568 does not exist.
# ZIP file for model 155601 does not exist.
# ZIP file for model 155602 does not exist.
# ZIP file for model 155705 does not exist.
# ZIP file for model 155727 does not exist.
# ZIP file for model 155731 does not exist.
# ZIP file for model 155735 does not exist.
# ZIP file for model 155796 does not exist.
# ZIP file for model 155856 does not exist.
# ZIP file for model 156027 does not exist.
# ZIP file for model 156039 does not exist.
# ZIP file for model 156072 does not exist.
# ZIP file for model 156120 does not exist.
# ZIP file for model 156162 does not exist.
# ZIP file for model 156260 does not exist.
# ZIP file for model 156470 does not exist.
# ZIP file for model 156733 does not exist.
# ZIP file for model 156780 does not exist.
# ZIP file for model 156781 does not exist.
# ZIP file for model 156828 does not exist.
# ZIP file for model 156830 does not exist.
# ZIP file for model 157157 does not exist.
# ZIP file for model 157339 does not exist.
# ZIP file for model 167414 does not exist.
# ZIP file for model 167499 does not exist.
# ZIP file for model 167638 does not exist.
# ZIP file for model 167694 does not exist.
# ZIP file for model 167714 does not exist.
# ZIP file for model 167715 does not exist.
# ZIP file for model 167772 does not exist.
# ZIP file for model 167875 does not exist.
# ZIP file for model 168143 does not exist.
# ZIP file for model 168148 does not exist.
# ZIP file for model 168310 does not exist.
# ZIP file for model 168314 does not exist.
# ZIP file for model 168407 does not exist.
# ZIP file for model 168414 does not exist.
# ZIP file for model 168418 does not exist.
# ZIP file for model 168590 does not exist.
# ZIP file for model 168591 does not exist.
# ZIP file for model 168599 does not exist.
# ZIP file for model 168856 does not exist.
# ZIP file for model 168858 does not exist.
# ZIP file for model 168861 does not exist.
# ZIP file for model 168866 does not exist.
# ZIP file for model 168867 does not exist.
# ZIP file for model 168874 does not exist.
# ZIP file for model 168950 does not exist.
# ZIP file for model 168957 does not exist.
# ZIP file for model 169023 does not exist.
# ZIP file for model 169208 does not exist.
# ZIP file for model 169240 does not exist.
# ZIP file for model 169242 does not exist.
# ZIP file for model 169278 does not exist.
# ZIP file for model 169457 does not exist.
# ZIP file for model 169775 does not exist.
# ZIP file for model 169983 does not exist.
# ZIP file for model 169984 does not exist.
# ZIP file for model 169985 does not exist.
# ZIP file for model 170029 does not exist.
# ZIP file for model 170030 does not exist.
# ZIP file for model 180370 does not exist.
# ZIP file for model 180372 does not exist.
# ZIP file for model 180373 does not exist.
# ZIP file for model 180789 does not exist.
# ZIP file for model 180791 does not exist.
# ZIP file for model 180823 does not exist.
# ZIP file for model 181010 does not exist.
# ZIP file for model 181032 does not exist.
# ZIP file for model 181035 does not exist.
# ZIP file for model 181962 does not exist.
# ZIP file for model 181967 does not exist.
# ZIP file for model 182129 does not exist.
# ZIP file for model 182134 does not exist.
# ZIP file for model 182135 does not exist.
# ZIP file for model 182142 does not exist.
# ZIP file for model 182373 does not exist.
# ZIP file for model 182515 does not exist.
# ZIP file for model 182685 does not exist.
# ZIP file for model 182758 does not exist.
# ZIP file for model 182759 does not exist.
# ZIP file for model 182784 does not exist.
# ZIP file for model 182785 does not exist.
# ZIP file for model 182797 does not exist.
# ZIP file for model 182843 does not exist.
# ZIP file for model 182906 does not exist.
# ZIP file for model 182988 does not exist.
# ZIP file for model 183014 does not exist.
# ZIP file for model 183015 does not exist.
# ZIP file for model 183017 does not exist.
# ZIP file for model 183077 does not exist.
# ZIP file for model 183251 does not exist.
# ZIP file for model 183300 does not exist.
# ZIP file for model 183371 does not exist.
# ZIP file for model 183424 does not exist.
# ZIP file for model 183718 does not exist.
# ZIP file for model 183722 does not exist.
# ZIP file for model 183948 does not exist.
# ZIP file for model 183949 does not exist.
# ZIP file for model 184054 does not exist.
# ZIP file for model 184139 does not exist.
# ZIP file for model 184140 does not exist.
# ZIP file for model 184141 does not exist.
# ZIP file for model 184142 does not exist.
# ZIP file for model 184145 does not exist.
# ZIP file for model 184148 does not exist.
# ZIP file for model 184152 does not exist.
# ZIP file for model 184157 does not exist.
# ZIP file for model 184159 does not exist.
# ZIP file for model 184161 does not exist.
# ZIP file for model 184163 does not exist.
# ZIP file for model 184166 does not exist.
# ZIP file for model 184168 does not exist.
# ZIP file for model 184171 does not exist.
# ZIP file for model 184173 does not exist.
# ZIP file for model 184175 does not exist.
# ZIP file for model 184176 does not exist.
# ZIP file for model 184178 does not exist.
# ZIP file for model 184180 does not exist.
# ZIP file for model 184182 does not exist.
# ZIP file for model 184184 does not exist.
# ZIP file for model 184186 does not exist.
# ZIP file for model 184196 does not exist.
# ZIP file for model 184202 does not exist.
# ZIP file for model 184231 does not exist.
# ZIP file for model 184274 does not exist.
# ZIP file for model 184297 does not exist.
# ZIP file for model 184299 does not exist.
# ZIP file for model 184301 does not exist.
# ZIP file for model 184303 does not exist.
# ZIP file for model 184305 does not exist.
# ZIP file for model 184308 does not exist.
# ZIP file for model 184310 does not exist.
# ZIP file for model 184312 does not exist.
# ZIP file for model 184314 does not exist.
# ZIP file for model 184316 does not exist.
# ZIP file for model 184319 does not exist.
# ZIP file for model 184321 does not exist.
# ZIP file for model 184323 does not exist.
# ZIP file for model 184325 does not exist.
# ZIP file for model 184327 does not exist.
# ZIP file for model 184329 does not exist.
# ZIP file for model 184331 does not exist.
# ZIP file for model 184333 does not exist.
# ZIP file for model 184335 does not exist.
# ZIP file for model 184337 does not exist.
# ZIP file for model 184339 does not exist.
# ZIP file for model 184341 does not exist.
# ZIP file for model 184344 does not exist.
# ZIP file for model 184346 does not exist.
# ZIP file for model 184348 does not exist.
# ZIP file for model 184350 does not exist.
# ZIP file for model 184352 does not exist.
# ZIP file for model 184404 does not exist.
# ZIP file for model 184410 does not exist.
# ZIP file for model 184479 does not exist.
# ZIP file for model 184487 does not exist.
# ZIP file for model 184491 does not exist.
# ZIP file for model 184497 does not exist.
# ZIP file for model 184545 does not exist.
# ZIP file for model 184725 does not exist.
# ZIP file for model 184731 does not exist.
# ZIP file for model 184732 does not exist.
# ZIP file for model 185014 does not exist.
# ZIP file for model 185021 does not exist.
# ZIP file for model 185090 does not exist.
# ZIP file for model 185122 does not exist.
# ZIP file for model 185123 does not exist.
# ZIP file for model 185300 does not exist.
# ZIP file for model 185328 does not exist.
# ZIP file for model 185330 does not exist.
# ZIP file for model 185332 does not exist.
# ZIP file for model 185334 does not exist.
# ZIP file for model 185338 does not exist.
# ZIP file for model 185350 does not exist.
# ZIP file for model 185355 does not exist.
# ZIP file for model 185464 does not exist.
# ZIP file for model 185512 does not exist.
# ZIP file for model 185513 does not exist.
# ZIP file for model 185858 does not exist.
# ZIP file for model 185864 does not exist.
# ZIP file for model 185875 does not exist.
# ZIP file for model 186768 does not exist.
# ZIP file for model 186977 does not exist.
# ZIP file for model 187213 does not exist.
# ZIP file for model 187473 does not exist.
# ZIP file for model 187474 does not exist.
# ZIP file for model 187599 does not exist.
# ZIP file for model 187600 does not exist.
# ZIP file for model 187603 does not exist.
# ZIP file for model 187604 does not exist.
# ZIP file for model 187605 does not exist.
# ZIP file for model 187610 does not exist.
# ZIP file for model 187615 does not exist.
# ZIP file for model 187687 does not exist.
# ZIP file for model 188423 does not exist.
# ZIP file for model 188543 does not exist.
# ZIP file for model 188544 does not exist.
# ZIP file for model 188552 does not exist.
# ZIP file for model 188977 does not exist.
# ZIP file for model 189088 does not exist.
# ZIP file for model 189153 does not exist.
# ZIP file for model 189154 does not exist.
# ZIP file for model 189155 does not exist.
# ZIP file for model 189160 does not exist.
# ZIP file for model 189186 does not exist.
# ZIP file for model 189308 does not exist.
# ZIP file for model 189344 does not exist.
# ZIP file for model 189346 does not exist.
# ZIP file for model 189347 does not exist.
# ZIP file for model 189786 does not exist.
# ZIP file for model 189922 does not exist.
# ZIP file for model 189946 does not exist.
# ZIP file for model 190140 does not exist.
# ZIP file for model 190261 does not exist.
# ZIP file for model 190304 does not exist.
# ZIP file for model 190306 does not exist.
# ZIP file for model 190311 does not exist.
# ZIP file for model 190559 does not exist.
# ZIP file for model 190565 does not exist.
# ZIP file for model 190610 does not exist.
# ZIP file for model 194881 does not exist.
# ZIP file for model 194882 does not exist.
# ZIP file for model 194883 does not exist.
# ZIP file for model 194897 does not exist.
# ZIP file for model 195206 does not exist.
# ZIP file for model 195555 does not exist.
# ZIP file for model 195569 does not exist.
# ZIP file for model 195615 does not exist.
# ZIP file for model 195626 does not exist.
# ZIP file for model 195658 does not exist.
# ZIP file for model 195659 does not exist.
# ZIP file for model 195666 does not exist.
# ZIP file for model 195667 does not exist.
# ZIP file for model 195731 does not exist.
# ZIP file for model 195856 does not exist.
# ZIP file for model 195886 does not exist.
# ...
# ZIP file for model 253369 does not exist.
# ZIP file for model 253624 does not exist.
# ZIP file for model 253991 does not exist.
# ZIP file for model 254217 does not exist.
# ZIP file for model 255569 does not exist.
# ZIP file for model 256021 does not exist.
# ZIP file for model 256024 does not exist.
# ZIP file for model 256028 does not exist.
# ZIP file for model 256140 does not exist.
# ZIP file for model 256311 does not exist.
# ZIP file for model 256370 does not exist.
# ZIP file for model 256388 does not exist.
# ZIP file for model 256610 does not exist.
# ZIP file for model 256624 does not exist.
# ZIP file for model 256627 does not exist.
# ZIP file for model 256628 does not exist.
# ZIP file for model 256632 does not exist.
# ZIP file for model 257027 does not exist.
# ZIP file for model 257028 does not exist.
# ZIP file for model 257608 does not exist.
# ZIP file for model 257609 does not exist.
# ZIP file for model 257610 does not exist.
# ZIP file for model 257631 does not exist.
# ZIP file for model 257747 does not exist.
# ZIP file for model 257877 does not exist.
# ZIP file for model 257940 does not exist.
# ZIP file for model 257965 does not exist.
# ZIP file for model 258234 does not exist.
# ZIP file for model 258235 does not exist.
# ZIP file for model 258478 does not exist.
# ZIP file for model 258631 does not exist.
# ZIP file for model 258643 does not exist.
# ZIP file for model 258738 does not exist.
# ZIP file for model 258807 does not exist.
# ZIP file for model 258844 does not exist.
# ZIP file for model 258846 does not exist.
# ZIP file for model 258854 does not exist.
# ZIP file for model 258867 does not exist.
# ZIP file for model 258946 does not exist.
# ZIP file for model 258949 does not exist.
# ZIP file for model 259261 does not exist.
# ZIP file for model 259366 does not exist.
# ZIP file for model 259542 does not exist.
# ZIP file for model 259546 does not exist.
# ZIP file for model 259620 does not exist.
# ZIP file for model 259732 does not exist.
# ZIP file for model 259786 does not exist.
# ZIP file for model 260178 does not exist.
# ZIP file for model 260190 does not exist.
# ZIP file for model 260192 does not exist.
# ZIP file for model 260210 does not exist.
# ZIP file for model 260267 does not exist.
# ZIP file for model 260596 does not exist.
# ZIP file for model 260653 does not exist.
# ZIP file for model 260730 does not exist.
# ZIP file for model 260740 does not exist.
# ZIP file for model 260949 does not exist.
# ZIP file for model 260960 does not exist.
# ZIP file for model 260967 does not exist.
# ZIP file for model 260971 does not exist.
# ZIP file for model 260972 does not exist.
# ZIP file for model 261078 does not exist.
# ZIP file for model 261423 does not exist.
# ZIP file for model 261435 does not exist.
# ZIP file for model 261436 does not exist.
# ZIP file for model 261460 does not exist.
# ZIP file for model 261461 does not exist.
# ZIP file for model 261466 does not exist.
# ZIP file for model 261483 does not exist.
# ZIP file for model 261489 does not exist.
# ZIP file for model 261585 does not exist.
# ZIP file for model 261616 does not exist.
# ZIP file for model 261623 does not exist.
# ZIP file for model 261624 does not exist.
# ZIP file for model 261709 does not exist.
# ZIP file for model 261714 does not exist.
# ZIP file for model 261864 does not exist.
# ZIP file for model 261873 does not exist.
# ZIP file for model 261877 does not exist.
# ZIP file for model 261878 does not exist.
# ZIP file for model 261881 does not exist.
# ZIP file for model 261882 does not exist.
# ZIP file for model 261899 does not exist.
# ZIP file for model 262045 does not exist.
# ZIP file for model 262046 does not exist.
# ZIP file for model 262059 does not exist.
# ZIP file for model 262060 does not exist.
# ZIP file for model 262081 does not exist.
# ZIP file for model 262114 does not exist.
# ZIP file for model 262115 does not exist.
# ZIP file for model 262138 does not exist.
# ZIP file for model 262187 does not exist.
# ZIP file for model 262233 does not exist.
# ZIP file for model 262356 does not exist.
# ZIP file for model 262368 does not exist.
# ZIP file for model 262373 does not exist.
# ZIP file for model 262389 does not exist.
# ZIP file for model 262422 does not exist.
# ZIP file for model 262431 does not exist.
# ZIP file for model 262452 does not exist.
# ZIP file for model 262456 does not exist.
# ZIP file for model 262457 does not exist.
# ZIP file for model 262464 does not exist.
# ZIP file for model 262465 does not exist.
# ZIP file for model 262670 does not exist.
# ZIP file for model 263034 does not exist.
# ZIP file for model 263042 does not exist.
# ZIP file for model 263053 does not exist.
# ZIP file for model 263074 does not exist.
# ZIP file for model 263130 does not exist.
# ZIP file for model 263193 does not exist.
# ZIP file for model 263196 does not exist.
# ZIP file for model 263199 does not exist.
# ZIP file for model 263236 does not exist.
# ZIP file for model 263246 does not exist.
# ZIP file for model 263259 does not exist.
# ZIP file for model 263571 does not exist.
# ZIP file for model 263585 does not exist.
# ZIP file for model 263637 does not exist.
# ZIP file for model 263703 does not exist.
# ZIP file for model 263705 does not exist.
# ZIP file for model 263711 does not exist.
# ZIP file for model 263718 does not exist.
# ZIP file for model 263719 does not exist.
# ZIP file for model 263956 does not exist.
# ZIP file for model 263961 does not exist.
# ZIP file for model 263988 does not exist.
# ZIP file for model 263992 does not exist.
# ZIP file for model 263995 does not exist.
# ZIP file for model 264177 does not exist.
# ZIP file for model 264514 does not exist.
# ZIP file for model 264519 does not exist.
# ZIP file for model 264539 does not exist.
# ZIP file for model 264591 does not exist.
# ZIP file for model 264594 does not exist.
# ZIP file for model 264597 does not exist.
# ZIP file for model 264628 does not exist.
# ZIP file for model 264834 does not exist.
# ZIP file for model 264842 does not exist.
# ZIP file for model 264844 does not exist.
# ZIP file for model 265511 does not exist.
# ZIP file for model 265523 does not exist.
# ZIP file for model 265528 does not exist.
# ZIP file for model 265540 does not exist.
# ZIP file for model 265584 does not exist.
# ZIP file for model 265591 does not exist.
# ZIP file for model 265592 does not exist.
# ZIP file for model 266415 does not exist.
# ZIP file for model 266419 does not exist.
# ZIP file for model 266435 does not exist.
# ZIP file for model 266488 does not exist.
# ZIP file for model 266492 does not exist.
# ZIP file for model 266497 does not exist.
# ZIP file for model 266498 does not exist.
# ZIP file for model 266506 does not exist.
# ZIP file for model 266508 does not exist.
# ZIP file for model 266518 does not exist.
# ZIP file for model 266524 does not exist.
# ZIP file for model 266526 does not exist.
# ZIP file for model 266534 does not exist.
# ZIP file for model 266535 does not exist.
# ZIP file for model 266551 does not exist.
# ZIP file for model 266552 does not exist.
# ZIP file for model 266555 does not exist.
# ZIP file for model 266560 does not exist.
# ZIP file for model 266577 does not exist.
# ZIP file for model 266578 does not exist.
# ZIP file for model 266584 does not exist.
# ZIP file for model 266609 does not exist.
# ZIP file for model 266636 does not exist.
# ZIP file for model 266637 does not exist.
# ZIP file for model 266657 does not exist.
# ZIP file for model 266663 does not exist.
# ZIP file for model 266687 does not exist.
# ZIP file for model 266718 does not exist.
# ZIP file for model 266720 does not exist.
# ZIP file for model 266726 does not exist.
# ZIP file for model 266732 does not exist.
# ZIP file for model 266770 does not exist.
# ZIP file for model 266774 does not exist.
# ZIP file for model 266775 does not exist.
# ZIP file for model 266782 does not exist.
# ZIP file for model 266794 does not exist.
# ZIP file for model 266796 does not exist.
# ZIP file for model 266798 does not exist.
# ZIP file for model 266799 does not exist.
# ZIP file for model 266800 does not exist.
# ZIP file for model 266802 does not exist.
# ZIP file for model 266806 does not exist.
# ZIP file for model 266807 does not exist.
# ZIP file for model 266811 does not exist.
# ZIP file for model 266814 does not exist.
# ZIP file for model 266818 does not exist.
# ZIP file for model 266819 does not exist.
# ZIP file for model 266823 does not exist.
# ZIP file for model 266836 does not exist.
# ZIP file for model 266837 does not exist.
# ZIP file for model 266839 does not exist.
# ZIP file for model 266840 does not exist.
# ZIP file for model 266841 does not exist.
# ZIP file for model 266842 does not exist.
# ZIP file for model 266848 does not exist.
# ZIP file for model 266849 does not exist.
# ZIP file for model 266850 does not exist.
# ZIP file for model 266851 does not exist.
# ZIP file for model 266863 does not exist.
# ZIP file for model 266864 does not exist.
# ZIP file for model 266868 does not exist.
# ZIP file for model 266871 does not exist.
# ZIP file for model 266872 does not exist.
# ZIP file for model 266880 does not exist.
# ZIP file for model 266881 does not exist.
# ZIP file for model 266895 does not exist.
# ZIP file for model 266900 does not exist.
# ZIP file for model 266901 does not exist.
# ZIP file for model 266902 does not exist.
# ZIP file for model 266905 does not exist.
# ZIP file for model 266910 does not exist.
# ZIP file for model 266925 does not exist.
# ZIP file for model 266928 does not exist.
# ZIP file for model 266929 does not exist.
# ZIP file for model 266933 does not exist.
# ZIP file for model 266941 does not exist.
# ZIP file for model 266948 does not exist.
# ZIP file for model 266954 does not exist.
# ZIP file for model 266961 does not exist.
# ZIP file for model 266974 does not exist.
# ZIP file for model 266980 does not exist.
# ZIP file for model 266984 does not exist.
# ZIP file for model 266989 does not exist.
# ZIP file for model 267009 does not exist.
# ZIP file for model 267010 does not exist.
# ZIP file for model 267013 does not exist.
# ZIP file for model 267018 does not exist.
# ZIP file for model 267023 does not exist.
# ZIP file for model 267026 does not exist.
# ZIP file for model 267027 does not exist.
# ZIP file for model 267033 does not exist.
# ZIP file for model 267035 does not exist.
# ZIP file for model 267039 does not exist.
# ZIP file for model 267046 does not exist.
# ZIP file for model 267047 does not exist.
# ZIP file for model 267048 does not exist.
# ZIP file for model 267049 does not exist.
# ZIP file for model 267050 does not exist.
# ZIP file for model 267056 does not exist.
# ZIP file for model 267063 does not exist.
# ZIP file for model 267066 does not exist.
# ZIP file for model 267067 does not exist.
# ZIP file for model 267073 does not exist.
# ZIP file for model 267086 does not exist.
# ZIP file for model 267093 does not exist.
# ZIP file for model 267103 does not exist.
# ZIP file for model 267106 does not exist.
# ZIP file for model 267116 does not exist.
# ZIP file for model 267120 does not exist.
# ZIP file for model 267128 does not exist.
# ZIP file for model 267132 does not exist.
# ZIP file for model 267139 does not exist.
# ZIP file for model 267140 does not exist.
# ZIP file for model 267142 does not exist.
# ZIP file for model 267145 does not exist.
# ZIP file for model 267146 does not exist.
# ZIP file for model 267157 does not exist.
# ZIP file for model 267165 does not exist.
# ZIP file for model 267173 does not exist.
# ZIP file for model 267174 does not exist.
# ZIP file for model 267176 does not exist.
# ZIP file for model 267183 does not exist.
# ZIP file for model 267184 does not exist.
# ZIP file for model 267187 does not exist.
# ZIP file for model 267189 does not exist.
# ZIP file for model 267201 does not exist.
# ZIP file for model 267219 does not exist.
# ZIP file for model 267221 does not exist.
# ZIP file for model 267222 does not exist.
# ZIP file for model 267250 does not exist.
# ZIP file for model 267253 does not exist.
# ZIP file for model 267259 does not exist.
# ZIP file for model 267280 does not exist.
# ZIP file for model 267286 does not exist.
# ZIP file for model 267293 does not exist.
# ZIP file for model 267295 does not exist.
# ZIP file for model 267297 does not exist.
# ZIP file for model 267298 does not exist.
# ZIP file for model 267306 does not exist.
# ZIP file for model 267307 does not exist.
# ZIP file for model 267309 does not exist.
# ZIP file for model 267310 does not exist.
# ZIP file for model 267311 does not exist.
# ZIP file for model 267318 does not exist.
# ZIP file for model 267324 does not exist.
# ZIP file for model 267329 does not exist.
# ZIP file for model 267334 does not exist.
# ZIP file for model 267338 does not exist.
# ZIP file for model 267339 does not exist.
# ZIP file for model 267355 does not exist.
# ZIP file for model 267357 does not exist.
# ZIP file for model 267363 does not exist.
# ZIP file for model 267382 does not exist.
# ZIP file for model 267384 does not exist.
# ZIP file for model 267391 does not exist.
# ZIP file for model 267395 does not exist.
# ZIP file for model 267499 does not exist.
# ZIP file for model 267508 does not exist.
# ZIP file for model 267509 does not exist.
# ZIP file for model 267510 does not exist.
# ZIP file for model 267511 does not exist.
# ZIP file for model 267512 does not exist.
# ZIP file for model 267531 does not exist.
# ZIP file for model 267550 does not exist.
# ZIP file for model 267551 does not exist.
# ZIP file for model 267552 does not exist.
# ZIP file for model 267561 does not exist.
# ZIP file for model 267562 does not exist.
# ZIP file for model 267563 does not exist.
# ZIP file for model 267564 does not exist.
# ZIP file for model 267565 does not exist.
# ZIP file for model 267566 does not exist.
# ZIP file for model 267583 does not exist.
# ZIP file for model 267586 does not exist.
# ZIP file for model 267587 does not exist.
# ZIP file for model 267594 does not exist.
# ZIP file for model 267595 does not exist.
# ZIP file for model 267610 does not exist.
# ZIP file for model 267611 does not exist.
# ZIP file for model 267617 does not exist.
# ZIP file for model 267619 does not exist.
# ZIP file for model 267621 does not exist.
# ZIP file for model 267646 does not exist.
# ZIP file for model 267647 does not exist.
# ZIP file for model 267666 does not exist.
# ZIP file for model 267669 does not exist.
# ZIP file for model 267680 does not exist.
# ZIP file for model 267682 does not exist.
# ZIP file for model 267686 does not exist.
# ZIP file for model 267691 does not exist.
# ZIP file for model 267695 does not exist.
# ZIP file for model 267696 does not exist.
# ZIP file for model 267710 does not exist.
# ZIP file for model 267728 does not exist.
# ZIP file for model 267589 does not exist.
# ZIP file for model 267596 does not exist.
# ZIP file for model 267614 does not exist.
# ZIP file for model 267735 does not exist.
# ZIP file for model 267736 does not exist.
# ZIP file for model 267260 does not exist.
# ZIP file for model 267738 does not exist.
# ZIP file for model 260015 does not exist.
# ZIP file for model 266844 does not exist.
# ZIP file for model 267754 does not exist.
# ZIP file for model 2001735 does not exist.
# ZIP file for model 241169 does not exist.
# ZIP file for model 266797 does not exist.
# ZIP file for model 267661 does not exist.
# ZIP file for model 267742 does not exist.
# ZIP file for model 2014814 does not exist.
# ZIP file for model 267591 does not exist.
# ZIP file for model 267620 does not exist.
# ZIP file for model 2014817 does not exist.
# ZIP file for model 267599 does not exist.
# ZIP file for model 267144 does not exist.
# ZIP file for model 2014825 does not exist.
# ZIP file for model 267618 does not exist.
# ZIP file for model 2014999 does not exist.
# ZIP file for model 2014830 does not exist.
# ZIP file for model 267768 does not exist.
# ZIP file for model 267598 does not exist.
# ZIP file for model 2015414 does not exist.
# ZIP file for model 2014996 does not exist.
# ZIP file for model 2015413 does not exist.
# ZIP file for model 2015412 does not exist.
# ZIP file for model 2015421 does not exist.
# ZIP file for model 2014998 does not exist.
# ZIP file for model 2014833 does not exist.
# ZIP file for model 267613 does not exist.
# ZIP file for model 2014816 does not exist.
# ZIP file for model 2015422 does not exist.
# ZIP file for model 2014822 does not exist.
# Models with non-matching ZIP files and GitHub repositories:

# %% [markdown]
# # Publications

# %%
import requests

# Define the ModelDB API endpoint
api_url = "https://modeldb.science/api/v1/models"

# Make an API request to get the list of model IDs
response = requests.get(api_url)
model_ids = response.json()

# Process a few models for inspection
for model_id in model_ids[:5]:  # Adjust the number for more or fewer models
    # Fetch metadata for the model
    model_data = requests.get(f"{api_url}/{model_id}").json()

    # Print the model ID and its metadata for inspection
    print(f"Model ID: {model_id}")
    print("Metadata:")
    print(model_data)
    print("\n")
# Out:
# Model ID: 279
# Metadata:
# {'id': 279, 'name': 'Low Threshold Calcium Currents in TC cells (Destexhe et al 1998)', 'created': '2001-01-01T00:00:00', 'ver_number': 24, 'ver_date': '2015-01-02T22:01:45', 'class_id': 19, 'notes': {'value': "In Destexhe, Neubig, Ulrich, and Huguenard (1998) experiments and models examine low threshold calcium current's (IT, or T-current) distribution in thalamocortical (TC) cells.  Multicompartmental modeling supports the hypothesis that IT currents have a density at least several fold higher in the dendrites than the soma.  The IT current contributes significantly to rebound bursts and is thought to have important network behavior consequences.  See the paper for details. See also http://cns.iaf.cnrs-gif.fr   Correspondance may be addressed to Alain Destexhe: Destexhe@iaf.cnrs-gif.fr", 'attr_id': 24}, 'neurons': {'value': [{'object_id': 262, 'object_name': 'Thalamus geniculate nucleus/lateral principal GLU cell'}], 'attr_id': 25}, 'currents': {'value': [{'object_id': 242, 'object_name': 'I Na,t'}, {'object_id': 245, 'object_name': 'I T low threshold'}, {'object_id': 248, 'object_name': 'I K'}], 'attr_id': 27}, 'model_type': {'value': [{'object_id': 3537, 'object_name': 'Neuron or other electrically excitable cell'}], 'attr_id': 112}, 'model_concept': {'value': [{'object_id': 3629, 'object_name': 'Dendritic Action Potentials'}, {'object_id': 3630, 'object_name': 'Bursting'}, {'object_id': 3631, 'object_name': 'Ion Channel Kinetics'}, {'object_id': 3637, 'object_name': 'Parameter Fitting'}, {'object_id': 3638, 'object_name': 'Simplified Models'}, {'object_id': 3640, 'object_name': 'Influence of Dendritic Geometry'}, {'object_id': 3641, 'object_name': 'Detailed Neuronal Models'}, {'object_id': 98012, 'object_name': 'Calcium dynamics'}, {'object_id': 136252, 'object_name': 'Rebound firing'}], 'attr_id': 113}, 'modeling_application': {'value': [{'object_id': 1882, 'object_name': 'NEURON'}], 'attr_id': 114}, 'model_paper': {'value': [{'object_id': 4161, 'object_name': 'Destexhe A, Neubig M, Ulrich D, Huguenard J (1998)'}], 'attr_id': 155}, 'implemented_by': {'value': [{'object_id': 33744, 'object_name': 'Destexhe, Alain [Destexhe at iaf.cnrs-gif.fr]'}], 'attr_id': 299}, 'simPFid': {'value': 275, 'attr_id': 488}, 'has_modelview': {'value': True, 'attr_id': 502}, 'hide_autolaunch_button': {'value': False, 'attr_id': 582}, 'runprotocols': {'value': [{'object_id': 181344, 'object_name': '279_4'}, {'object_id': 181345, 'object_name': '279_5'}, {'object_id': 181346, 'object_name': '279_2'}, {'object_id': 181347, 'object_name': '279_3'}, {'object_id': 181348, 'object_name': '279_1'}], 'attr_id': 613}, 'gitrepo': True, 'modelviews': {'all': [{'name': 'Burst behavior in single-compartment model', 'id': '279_1'}, {'name': 'Burst behavior in 3-compartment model', 'id': '279_2'}, {'name': 'Burst behavior in detailed cell model', 'id': '279_3'}, {'name': 'Voltage-clamp in detailed cell model', 'id': '279_4'}, {'name': 'Voltage-clamp in dissociated cell model', 'id': '279_5'}], 'default': '279_1'}}
#
#
# Model ID: 2487
# Metadata:
# {'id': 2487, 'name': 'Olfactory Mitral Cell (Davison et al 2000)', 'created': '2001-04-05T22:35:35', 'ver_number': 14, 'ver_date': '2022-05-27T18:13:12.8', 'class_id': 19, 'notes': {'value': 'A four-compartment model of a mammalian olfactory bulb mitral cell, reduced \r\nfrom the complex 286-compartment model described by Bhalla and Bower (1993).  \r\nThe compartments are soma/axon, secondary dendrites, primary dendrite shaft \r\nand primary dendrite tuft. The reduced model runs 75 or more times faster \r\nthan the full model, making its use in large, realistic network models of the \r\nolfactory bulb practical.', 'attr_id': 24}, 'neurons': {'value': [{'object_id': 267, 'object_name': 'Olfactory bulb main mitral GLU cell'}], 'attr_id': 25}, 'currents': {'value': [{'object_id': 242, 'object_name': 'I Na,t'}, {'object_id': 243, 'object_name': 'I L high threshold'}, {'object_id': 247, 'object_name': 'I A'}, {'object_id': 248, 'object_name': 'I K'}, {'object_id': 249, 'object_name': 'I K,leak'}, {'object_id': 253, 'object_name': 'I K,Ca'}, {'object_id': 2395, 'object_name': 'I Sodium'}, {'object_id': 2396, 'object_name': 'I Calcium'}, {'object_id': 2405, 'object_name': 'I Potassium'}], 'attr_id': 27}, 'model_type': {'value': [{'object_id': 3537, 'object_name': 'Neuron or other electrically excitable cell'}], 'attr_id': 112}, 'model_concept': {'value': [{'object_id': 3637, 'object_name': 'Parameter Fitting'}, {'object_id': 3638, 'object_name': 'Simplified Models'}, {'object_id': 245690, 'object_name': 'Olfaction'}], 'attr_id': 113}, 'modeling_application': {'value': [{'object_id': 1882, 'object_name': 'NEURON'}], 'attr_id': 114}, 'model_paper': {'value': [{'object_id': 4036, 'object_name': 'Davison AP, Feng J, Brown D (2000)'}], 'attr_id': 155}, 'implemented_by': {'value': [{'object_id': 33739, 'object_name': 'Davison, Andrew [Andrew.Davison at iaf.cnrs-gif.fr]'}], 'attr_id': 299}, 'simPFid': {'value': 304, 'attr_id': 488}, 'has_modelview': {'value': True, 'attr_id': 502}, 'hide_autolaunch_button': {'value': False, 'attr_id': 582}, 'runprotocols': {'value': [{'object_id': 181441, 'object_name': '2487_4'}, {'object_id': 181443, 'object_name': '2487_2'}, {'object_id': 181444, 'object_name': '2487_3'}, {'object_id': 181445, 'object_name': '2487_1'}], 'attr_id': 613}, 'gitrepo': False, 'modelviews': {'all': [{'name': 'Stimulate soma with 0.2 uA/cm2', 'id': '2487_1'}, {'name': 'Stimulate soma with 1.6 uA/cm2', 'id': '2487_2'}, {'name': 'Stimulate glomerulus with 0.2 uA/cm2', 'id': '2487_3'}, {'name': 'Stimulate glomerulus with 1.6 uA/cm2', 'id': '2487_4'}], 'default': '2487_1'}}
#
#
# Model ID: 2488
# Metadata:
# {'id': 2488, 'name': 'Influence of dendritic structure on neocortical neuron firing patterns (Mainen and Sejnowski 1996)', 'created': '2001-04-05T22:36:18', 'ver_number': 24, 'ver_date': '2018-11-16T15:29:16.747', 'class_id': 19, 'notes': {'value': 'This package contains compartmental models of four reconstructed neocortical neurons (layer 3 Aspiny, layer 4 Stellate, layer 3 and layer 5 Pyramidal neurons) with active dendritic currents using NEURON.  Running this simulation demonstrates that an entire spectrum of firing patterns can be reproduced in this set of model neurons which share a common distribution of ion channels and differ only in their dendritic geometry. The reference paper is: Z. F. Mainen and T. J. Sejnowski (1996) Influence of dendritic structure on firing pattern in model neocortical neurons.  Nature 382: 363-366. See also http://www.cnl.salk.edu/~zach/methods.html and http://www.cnl.salk.edu/~zach/  More info in readme.txt file below made visible by clicking on the patdemo folder and then on the readme.txt file.', 'attr_id': 24}, 'neurons': {'value': [{'object_id': 265, 'object_name': 'Neocortex L5/6 pyramidal GLU cell'}, {'object_id': 266, 'object_name': 'Neocortex L2/3 pyramidal GLU cell'}, {'object_id': 52425, 'object_name': 'Myelinated neuron'}, {'object_id': 114635, 'object_name': 'Neocortex spiny stellate cell'}], 'attr_id': 25}, 'currents': {'value': [{'object_id': 242, 'object_name': 'I Na,t'}, {'object_id': 248, 'object_name': 'I K'}, {'object_id': 250, 'object_name': 'I M'}, {'object_id': 253, 'object_name': 'I K,Ca'}, {'object_id': 2395, 'object_name': 'I Sodium'}, {'object_id': 2396, 'object_name': 'I Calcium'}, {'object_id': 2405, 'object_name': 'I Potassium'}], 'attr_id': 27}, 'model_type': {'value': [{'object_id': 3537, 'object_name': 'Neuron or other electrically excitable cell'}], 'attr_id': 112}, 'model_concept': {'value': [{'object_id': 3543, 'object_name': 'Activity Patterns'}, {'object_id': 3639, 'object_name': 'Active Dendrites'}, {'object_id': 3640, 'object_name': 'Influence of Dendritic Geometry'}, {'object_id': 3641, 'object_name': 'Detailed Neuronal Models'}], 'attr_id': 113}, 'modeling_application': {'value': [{'object_id': 1882, 'object_name': 'NEURON'}], 'attr_id': 114}, 'model_paper': {'value': [{'object_id': 4252, 'object_name': 'Mainen ZF, Sejnowski TJ (1996)'}], 'attr_id': 155}, 'implemented_by': {'value': [{'object_id': 33763, 'object_name': 'Mainen, Zach [Mainen at cshl.edu]'}], 'attr_id': 299}, 'simPFid': {'value': 315, 'attr_id': 488}, 'has_modelview': {'value': True, 'attr_id': 502}, 'hide_autolaunch_button': {'value': False, 'attr_id': 582}, 'runprotocols': {'value': [{'object_id': 181358, 'object_name': '2488_4'}, {'object_id': 181361, 'object_name': '2488_1'}, {'object_id': 181363, 'object_name': '2488_3'}, {'object_id': 181364, 'object_name': '2488_2'}, {'object_id': 181648, 'object_name': '2488_5'}], 'attr_id': 613}, 'gitrepo': True, 'modelviews': {'all': [{'name': '1a. L3 Aspiny', 'id': '2488_1'}, {'name': '1b. L4 Stellate', 'id': '2488_2'}, {'name': '1c. L3 Pyramid', 'id': '2488_3'}, {'name': '1d. L5 Pyramid', 'id': '2488_4'}, {'name': '2', 'id': '2488_5'}], 'default': '2488_4'}}
# Model ID: 2730
# Metadata:
# {'id': 2730, 'name': 'Olfactory Bulb Network (Davison et al 2003)', 'created': '2001-05-16T10:13:42', 'ver_number': 50, 'ver_date': '2022-05-27T18:15:00.95', 'class_id': 19, 'notes': {'value': 'A biologically-detailed model of the mammalian olfactory bulb, incorporating \r\nthe mitral and granule cells and the dendrodendritic synapses between them. \r\nThe results of simulation experiments with electrical stimulation agree \r\nclosely in most details with published experimental data. The model predicts \r\nthat the time course of dendrodendritic inhibition is dependent on the \r\nnetwork connectivity as well as on the intrinsic parameters of the synapses. \r\nIn response to simulated odor stimulation, strongly activated mitral cells \r\ntend to suppress neighboring cells, the mitral cells readily synchronize \r\ntheir firing, and increasing the stimulus intensity increases the degree of \r\nsynchronization. For more details, see the reference below.', 'attr_id': 24}, 'neurons': {'value': [{'object_id': 267, 'object_name': 'Olfactory bulb main mitral GLU cell'}, {'object_id': 3979, 'object_name': 'Olfactory bulb main interneuron granule MC GABA cell'}], 'attr_id': 25}, 'currents': {'value': [{'object_id': 242, 'object_name': 'I Na,t'}, {'object_id': 243, 'object_name': 'I L high threshold'}, {'object_id': 247, 'object_name': 'I A'}, {'object_id': 248, 'object_name': 'I K'}, {'object_id': 249, 'object_name': 'I K,leak'}, {'object_id': 250, 'object_name': 'I M'}, {'object_id': 253, 'object_name': 'I K,Ca'}, {'object_id': 2395, 'object_name': 'I Sodium'}, {'object_id': 2396, 'object_name': 'I Calcium'}, {'object_id': 2405, 'object_name': 'I Potassium'}], 'attr_id': 27}, 'receptors': {'value': [{'object_id': 202, 'object_name': 'GabaA'}, {'object_id': 205, 'object_name': 'AMPA'}, {'object_id': 206, 'object_name': 'NMDA'}], 'attr_id': 26}, 'model_type': {'value': [{'object_id': 3536, 'object_name': 'Realistic Network'}], 'attr_id': 112}, 'model_concept': {'value': [{'object_id': 3634, 'object_name': 'Oscillations'}, {'object_id': 3635, 'object_name': 'Synchronization'}, {'object_id': 3636, 'object_name': 'Spatio-temporal Activity Patterns'}, {'object_id': 245690, 'object_name': 'Olfaction'}], 'attr_id': 113}, 'modeling_application': {'value': [{'object_id': 1882, 'object_name': 'NEURON'}], 'attr_id': 114}, 'model_paper': {'value': [{'object_id': 22120, 'object_name': 'Davison AP, Feng J, Brown D (2003)'}], 'attr_id': 155}, 'region': {'value': [{'object_id': 115950, 'object_name': 'Olfactory bulb'}], 'attr_id': 471}, 'implemented_by': {'value': [{'object_id': 33739, 'object_name': 'Davison, Andrew [Andrew.Davison at iaf.cnrs-gif.fr]'}], 'attr_id': 299}, 'neurotransmitters': {'value': [{'object_id': 232, 'object_name': 'Gaba'}, {'object_id': 233, 'object_name': 'Glutamate'}], 'attr_id': 28}, 'simPFid': {'value': 302, 'attr_id': 488}, 'has_modelview': {'value': True, 'attr_id': 502}, 'hide_autolaunch_button': {'value': False, 'attr_id': 582}, 'runprotocols': {'value': [{'object_id': 181170, 'object_name': '2730_2'}, {'object_id': 181171, 'object_name': '2730_1'}], 'attr_id': 613}, 'gitrepo': True, 'modelviews': {'all': [{'name': 'Fig 2 (Olfactory nerve shock)', 'id': '2730_1'}], 'default': '2730_1'}}
#
#
# Model ID: 2733
# Metadata:
# {'id': 2733, 'name': 'Olfactory Mitral Cell (Bhalla, Bower 1993)', 'created': '2001-05-18T15:26:52', 'ver_number': 29, 'ver_date': '2022-05-27T18:16:56.667', 'class_id': 19, 'notes': {'value': "This is a conversion to NEURON of the mitral cell model described in Bhalla \r\nand Bower (1993). \r\nThe original model was written in GENESIS and is available by joining BABEL, the GENESIS users' group here http://www.genesis-sim.org/GENESIS/babel.html", 'attr_id': 24}, 'neurons': {'value': [{'object_id': 267, 'object_name': 'Olfactory bulb main mitral GLU cell'}], 'attr_id': 25}, 'currents': {'value': [{'object_id': 242, 'object_name': 'I Na,t'}, {'object_id': 243, 'object_name': 'I L high threshold'}, {'object_id': 247, 'object_name': 'I A'}, {'object_id': 248, 'object_name': 'I K'}, {'object_id': 249, 'object_name': 'I K,leak'}, {'object_id': 253, 'object_name': 'I K,Ca'}, {'object_id': 2395, 'object_name': 'I Sodium'}, {'object_id': 2396, 'object_name': 'I Calcium'}, {'object_id': 2405, 'object_name': 'I Potassium'}], 'attr_id': 27}, 'model_type': {'value': [{'object_id': 3537, 'object_name': 'Neuron or other electrically excitable cell'}], 'attr_id': 112}, 'model_concept': {'value': [{'object_id': 3543, 'object_name': 'Activity Patterns'}, {'object_id': 3637, 'object_name': 'Parameter Fitting'}, {'object_id': 3640, 'object_name': 'Influence of Dendritic Geometry'}, {'object_id': 3641, 'object_name': 'Detailed Neuronal Models'}, {'object_id': 245690, 'object_name': 'Olfaction'}], 'attr_id': 113}, 'modeling_application': {'value': [{'object_id': 1882, 'object_name': 'NEURON'}], 'attr_id': 114}, 'model_paper': {'value': [{'object_id': 4675, 'object_name': 'Bhalla US, Bower JM (1993)'}], 'attr_id': 155}, 'implemented_by': {'value': [{'object_id': 33739, 'object_name': 'Davison, Andrew [Andrew.Davison at iaf.cnrs-gif.fr]'}], 'attr_id': 299}, 'simPFid': {'value': 303, 'attr_id': 488}, 'has_modelview': {'value': True, 'attr_id': 502}, 'hide_autolaunch_button': {'value': False, 'attr_id': 582}, 'gitrepo': True, 'modelviews': {'all': [{'name': 'ModelView', 'id': '2733'}], 'default': '2733'}}

# %%
import requests
import pandas as pd
from tqdm import tqdm
import re

# Function to check for paper title and identify DOI/PMID
def check_paper_details(paper_data):
    # Initialize default values
    paper_title = 'No Title'
    paper_attached = 'No'
    identifier_info = 'None'

    # Define regex patterns for DOI and PMID
    doi_pattern = re.compile(r'10.\d{4,9}/[-._;()/:A-Z0-9]+', re.IGNORECASE)
    pmid_pattern = re.compile(r'PMID:\s*\d+')

    # Check if there is a paper title
    if paper_data:
        paper_title = paper_data[0].get('object_name', 'No Title Provided')
        paper_attached = 'Yes'  # If there is a title, assume paper is attached
        
        # Search for DOI or PMID within the title
        if doi_pattern.search(paper_title):
            identifier_info = 'DOI Present'
        elif pmid_pattern.search(paper_title):
            identifier_info = 'PMID Present'
        elif 'http' in paper_title.lower():
            identifier_info = 'URL Present'
        else:
            identifier_info = 'Title Only'

    return paper_title, paper_attached, identifier_info

# Define the ModelDB API endpoint
api_url = "https://modeldb.science/api/v1/models"

# Make an API request to get the list of model IDs
response = requests.get(api_url)
model_ids = response.json()

# Prepare a list to store the results
results = []

# Process each model with a progress bar
for model_id in tqdm(model_ids, desc="Processing Model Papers"):
    # Fetch metadata for the model
    model_data = requests.get(f"{api_url}/{model_id}").json()

    # Extract paper information
    model_paper = model_data.get('model_paper', {}).get('value', [])

    # Check for paper title and if a paper is attached
    paper_title, paper_attached, identifier_info = check_paper_details(model_paper)

    # Append results
    results.append({
        "Model ID": model_id,
        "Paper Title": paper_title,
        "Paper Attached": paper_attached,
        "Identifier Information": identifier_info
    })

# Create a DataFrame from the results
df = pd.DataFrame(results)

# Save the DataFrame to a CSV file
output_file = "modeldb_paper_details.csv"
df.to_csv(output_file, index=False)

print(f"Data exported to CSV successfully. File location: {output_file}")
# Out:
# Processing Model Papers: 100%|██████████| 1838/1838 [03:23<00:00,  9.05it/s]
# Data exported to CSV successfully. File location: modeldb_paper_details.csv

# %%
pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in c:\users\polin\anaconda3\lib\site-packages (2.28.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\polin\anaconda3\lib\site-packages (4.11.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\polin\anaconda3\lib\site-packages (from requests) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\polin\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\polin\anaconda3\lib\site-packages (from requests) (2023.11.17)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\polin\anaconda3\lib\site-packages (from requests) (1.26.11)
# Requirement already satisfied: soupsieve>1.2 in c:\users\polin\anaconda3\lib\site-packages (from beautifulsoup4) (2.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

def check_doi_pmid(modeldb_id):
    url = f"https://modeldb.science/{modeldb_id}?tab=7"
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to retrieve data from {url}")
        return

    soup = BeautifulSoup(response.text, 'html.parser')

    # Look for DOI or PMID in the webpage
    # This part may require adjustments based on the webpage's structure
    has_doi = soup.find(string="DOI")
    has_pmid = soup.find(string="PMID")

    if has_doi or has_pmid:
        print(f"ModelDB entry {modeldb_id} has associated DOI or PMID.")
    else:
        print(f"ModelDB entry {modeldb_id} does NOT have associated DOI or PMID.")

# Example usage
modeldb_id = "245071"  # Replace with the ModelDB ID you want to check
check_doi_pmid(modeldb_id)
# Out:
# ModelDB entry 245071 does NOT have associated DOI or PMID.

# %%
import requests
import pandas as pd
from tqdm import tqdm
import re

# Function to check for paper title and identify DOI/PMID
def check_paper_details(paper_data):
    # Initialize default values
    paper_title = 'No Title'
    paper_attached = 'No'
    identifier_info = 'None'

    # Define regex patterns for DOI and PMID
    doi_pattern = re.compile(r'10\.\d{4,9}/[-._;()/:A-Z0-9]+', re.IGNORECASE)
    pmid_pattern = re.compile(r'PMID:\s*\d+')

    # Check if there is a paper title
    if paper_data:
        paper_title = paper_data[0].get('object_name', 'No Title Provided')
        paper_attached = 'Yes'  # If there is a title, assume paper is attached
        
        # Search for DOI or PMID within the title
        if doi_pattern.search(paper_title):
            identifier_info = 'DOI Present'
        elif pmid_pattern.search(paper_title):
            identifier_info = 'PMID Present'
        elif 'http' in paper_title.lower():
            identifier_info = 'URL Present'
        else:
            identifier_info = 'Title Only'

    return paper_title, paper_attached, identifier_info

# Define the ModelDB API endpoint
api_url = "https://modeldb.science/api/v1/models"

# Make an API request to get the list of model IDs
response = requests.get(api_url)
model_ids = response.json()

# Prepare a list to store the results
results = []

# Process each model with a progress bar
for model_id in tqdm(model_ids, desc="Processing Model Papers"):
    # Fetch metadata for the model
    model_data = requests.get(f"{api_url}/{model_id}").json()

    # Extract paper information
    model_paper = model_data.get('model_paper', {}).get('value', [])

    # Check for paper title and if a paper is attached
    paper_title, paper_attached, identifier_info = check_paper_details(model_paper)

    # Append results
    results.append({
        "Model ID": model_id,
        "Paper Title": paper_title,
        "Paper Attached": paper_attached,
        "Identifier Information": identifier_info
    })

# Create a DataFrame from the results
df = pd.DataFrame(results)

# Save the DataFrame to a CSV file
output_file = "modeldb_paper_details.csv"
df.to_csv(output_file, index=False)

print(f"Data exported to CSV successfully. File location: {output_file}")
# Out:
# Processing Model Papers: 100%|██████████| 1842/1842 [08:14<00:00,  3.73it/s]
# Data exported to CSV successfully. File location: modeldb_paper_details.csv

# %%
import requests
import pandas as pd
from tqdm import tqdm
import re

# Function to check for paper title and identify DOI/PMID
def check_paper_details(paper_data):
    # Initialize default values
    paper_title = 'No Title'
    paper_attached = 'No'
    identifier_info = 'None'

    # Define regex patterns for DOI and PMID
    doi_pattern = re.compile(r'10\.\d{4,9}/[-._;()/:A-Z0-9]+', re.IGNORECASE)
    pmid_pattern = re.compile(r'PMID:\s*\d+')

    # Check if there is a paper title
    if paper_data:
        paper_title = paper_data[0].get('object_name', 'No Title Provided')
        paper_attached = 'Yes'  # If there is a title, assume paper is attached
        
        # Search for DOI or PMID within the title
        if doi_pattern.search(paper_title):
            identifier_info = 'DOI Present'
        elif pmid_pattern.search(paper_title):
            identifier_info = 'PMID Present'
        elif 'http' in paper_title.lower():
            identifier_info = 'URL Present'
        else:
            identifier_info = 'Title Only'

    return paper_title, paper_attached, identifier_info

# Define the ModelDB API endpoint
api_url = "https://modeldb.science/api/v1/models"

# Make an API request to get the list of model IDs
response = requests.get(api_url)
model_ids = response.json()

# Prepare a list to store the results
results = []

# Process each model with a progress bar
for model_id in tqdm(model_ids, desc="Processing Model Papers"):
    # Fetch metadata for the model
    model_data = requests.get(f"{api_url}/{model_id}").json()

    # Extract paper information
    model_paper = model_data.get('model_paper', {}).get('value', [])

    # Check for paper title and if a paper is attached
    paper_title, paper_attached, identifier_info = check_paper_details(model_paper)

    # Append results
    results.append({
        "Model ID": model_id,
        "Paper Title": paper_title,
        "Paper Attached": paper_attached,
        "Identifier Information": identifier_info
    })

# Create a DataFrame from the results
df = pd.DataFrame(results)

# Save the original DataFrame to a CSV file
original_output_file = "modeldb_paper_details_1.csv"
df.to_csv(original_output_file, index=False)

# Create a DataFrame containing entries with missing information
missing_info_df = df[(df["Paper Title"] == 'No Title') | (df["Paper Attached"] == 'No') | (df["Identifier Information"] == 'None')]

# Save the DataFrame with missing information to a CSV file
missing_info_output_file = "modeldb_missing_info.csv"
missing_info_df.to_csv(missing_info_output_file, index=False)

print(f"Data exported to CSV successfully.")
print(f"Original data saved to {original_output_file}")
print(f"Missing information data saved to {missing_info_output_file}")
# Out:
# Processing Model Papers: 100%|██████████| 1842/1842 [05:47<00:00,  5.30it/s]
# Data exported to CSV successfully.
# Original data saved to modeldb_paper_details_1.csv
# Missing information data saved to modeldb_missing_info.csv

# %%
import requests
import pandas as pd
from tqdm import tqdm
import re

# Function to check for paper title and identify DOI/PMID
def check_paper_details(paper_data):
    # Initialize default values
    paper_title = 'No Title'
    paper_attached = 'No'
    identifier_info = 'None'

    # Define regex patterns for DOI and PMID
    doi_pattern = re.compile(r'10\.\d{4,9}/[-._;()/:A-Z0-9]+', re.IGNORECASE)
    pmid_pattern = re.compile(r'PMID:\s*\d+')

    # Check if there is a paper title
    if paper_data:
        paper_title = paper_data[0].get('object_name', 'No Title Provided')
        
        # Check if the title is empty or only contains whitespace
        if paper_title.strip():
            paper_attached = 'Yes'  # If there is a non-empty title, assume paper is attached
            
            # Search for DOI or PMID within the title
            if doi_pattern.search(paper_title):
                identifier_info = 'DOI Present'
            elif pmid_pattern.search(paper_title):
                identifier_info = 'PMID Present'
            elif 'http' in paper_title.lower():
                identifier_info = 'URL Present'
            else:
                identifier_info = 'Title Only'

    return paper_title, paper_attached, identifier_info

# Define the ModelDB API endpoint
api_url = "https://modeldb.science/api/v1/models"

# Make an API request to get the list of model IDs
response = requests.get(api_url)
model_ids = response.json()

# Prepare a list to store the results
results = []

# Process each model with a progress bar
for model_id in tqdm(model_ids, desc="Processing Model Papers"):
    # Fetch metadata for the model
    model_data = requests.get(f"{api_url}/{model_id}").json()

    # Extract paper information
    model_paper = model_data.get('model_paper', {}).get('value', [])

    # Check for paper title and if a paper is attached
    paper_title, paper_attached, identifier_info = check_paper_details(model_paper)

    # Append results
    results.append({
        "Model ID": model_id,
        "Paper Title": paper_title,
        "Paper Attached": paper_attached,
        "Identifier Information": identifier_info
    })

# Create a DataFrame from the results
df = pd.DataFrame(results)

# Save the original DataFrame to a CSV file
original_output_file = "modeldb_paper_details_2.csv"
df.to_csv(original_output_file, index=False)

# Create a DataFrame containing entries with missing information
missing_info_df = df[(df["Paper Title"] == 'No Title') | (df["Paper Attached"] == 'No') | (df["Identifier Information"] == 'None')]

# Save the DataFrame with missing information to a CSV file
missing_info_output_file = "modeldb_missing_info_2.csv"
missing_info_df.to_csv(missing_info_output_file, index=False)

print(f"Data exported to CSV successfully.")
print(f"Original data saved to {original_output_file}")
print(f"Missing information data saved to {missing_info_output_file}")
# Out:
# Processing Model Papers: 100%|██████████| 1842/1842 [05:23<00:00,  5.70it/s]
# Data exported to CSV successfully.
# Original data saved to modeldb_paper_details_2.csv
# Missing information data saved to modeldb_missing_info_2.csv

# %%
import requests
from bs4 import BeautifulSoup

def check_doi_pmid(modeldb_id):
    url = f"https://modeldb.science/{modeldb_id}?tab=7"
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to retrieve data from {url}")
        return

    soup = BeautifulSoup(response.text, 'html.parser')

    # Look for DOI or PMID in the webpage
    doi_element = soup.find("a", string="DOI")
    pmid_element = soup.find("a", string="PubMed")

    if doi_element:
        doi = doi_element.get("href")
        print(f"ModelDB entry {modeldb_id} has associated DOI: {doi}")
    elif pmid_element:
        pmid = pmid_element.get("href")
        print(f"ModelDB entry {modeldb_id} has associated PMID: {pmid}")
    else:
        print(f"ModelDB entry {modeldb_id} does NOT have associated DOI or PMID.")

# Example usage
modeldb_id = "245071"  # Replace with the ModelDB ID you want to check
check_doi_pmid(modeldb_id)
# Out:
# ModelDB entry 245071 does NOT have associated DOI or PMID.

# %%
import requests
from bs4 import BeautifulSoup

def check_doi_pmid(modeldb_id):
    url = f"https://modeldb.science/{modeldb_id}?tab=7"
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to retrieve data from {url}")
        return

    soup = BeautifulSoup(response.text, 'html.parser')

    # Look for DOI or PMID in the webpage
    doi_element = soup.find("a", string="DOI")
    pmid_element = soup.find("a", string="PubMed")

    if doi_element:
        doi = doi_element.get("href")
        return modeldb_id, f"DOI: {doi}"
    elif pmid_element:
        pmid = pmid_element.get("href")
        return modeldb_id, f"PMID: {pmid}"
    else:
        return modeldb_id, "No DOI or PMID"

# Fetch the list of ModelDB IDs from the API
api_url = "https://modeldb.science/api/v1/models"
response = requests.get(api_url)
if response.status_code != 200:
    print(f"Failed to retrieve the list of ModelDB IDs from {api_url}")
    exit()

modeldb_ids_to_check = response.json()

# Example usage to check all ModelDB entries
for modeldb_id in modeldb_ids_to_check:
    result = check_doi_pmid(modeldb_id)
    print(f"ModelDB entry {result[0]} - {result[1]}")
# Out:
# ModelDB entry 279 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=9570789
# ModelDB entry 2487 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=10715559
# ModelDB entry 2488 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=8684467
# ModelDB entry 2730 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=12736241
# ModelDB entry 2733 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=7688798
# ModelDB entry 2796 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=10481998
# ModelDB entry 2798 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=11158631
# ModelDB entry 2937 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=8913580
# ModelDB entry 3167 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=11731535
# ModelDB entry 3263 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=7608762
# ModelDB entry 3264 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=9315911
# ModelDB entry 3289 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=10856117
# ModelDB entry 3332 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=10938307
# ModelDB entry 3342 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=10601436
# ModelDB entry 3343 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=8890314
# ModelDB entry 3344 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=1491259
# ModelDB entry 3434 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=9607764
# ModelDB entry 3454 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=9547392
# ModelDB entry 3457 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=11371174
# ModelDB entry 3483 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=11371174
# ModelDB entry 3488 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=11371174
# ModelDB entry 3491 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=7551182
# ModelDB entry 3493 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=7473261
# ModelDB entry 3507 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=14191481
# ModelDB entry 3509 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=6315857
# ModelDB entry 3511 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=9634571
# ModelDB entry 3533 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=10662820
# ModelDB entry 3648 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=8745279
# ModelDB entry 3658 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=15784271
# ModelDB entry 3660 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=8871190
# ModelDB entry 3665 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=11568648
# ModelDB entry 3670 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=7527077
# ModelDB entry 3673 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=9325362
# ModelDB entry 3676 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=11588203
# ModelDB entry 3677 - PMID: https://www.ncbi.nlm.nih.gov/pubmed?holding=modeldb&term=9570781
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14980\250785648.py in <module>
#      36 for modeldb_id in modeldb_ids_to_check:
#      37     result = check_doi_pmid(modeldb_id)
# ---> 38     print(f"ModelDB entry {result[0]} - {result[1]}")
#
# ~\anaconda3\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     553                 self.pub_thread.schedule(self._flush)
#     554             else:
# --> 555                 self._schedule_flush()
#     556
#     557         return len(string)
#
# ~\anaconda3\lib\site-packages\ipykernel\iostream.py in _schedule_flush(self)
#     459             self._io_loop.call_later(self.flush_interval, self._flush)
#     460
# --> 461         self.pub_thread.schedule(_schedule_in_thread)
#     462
#     463     def flush(self):
#
# ~\anaconda3\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     208             self._events.append(f)
#     209             # wake event thread (message content is ignored)
# --> 210             self._event_pipe.send(b"")
#     211         else:
#     212             f()
#
# ~\anaconda3\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     616                 )
#     617             data.group = group
# --> 618         return super().send(data, flags=flags, copy=copy, track=track)
#     619
#     620     def send_multipart(
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~\anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from tqdm import tqdm

def check_doi_pmid(modeldb_id):
    url = f"https://modeldb.science/{modeldb_id}?tab=7"
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to retrieve data from {url}")
        return None

    soup = BeautifulSoup(response.text, 'html.parser')

    # Look for DOI or PMID in the webpage
    doi_element = soup.find("a", string="DOI")
    pmid_element = soup.find("a", string="PubMed")

    if doi_element:
        doi = doi_element.get("href")
        return modeldb_id, f"DOI: {doi}"
    elif pmid_element:
        pmid = pmid_element.get("href")
        return modeldb_id, f"PMID: {pmid}"
    else:
        return None

# Fetch the list of ModelDB IDs from the API
api_url = "https://modeldb.science/api/v1/models"
response = requests.get(api_url)
if response.status_code != 200:
    print(f"Failed to retrieve the list of ModelDB IDs from {api_url}")
    exit()

modeldb_ids_to_check = response.json()

# Initialize a list to store the results
results = []

# Check all ModelDB entries for DOI or PMID and store the results
with tqdm(total=len(modeldb_ids_to_check), desc="Checking ModelDB Entries") as pbar:
    for modeldb_id in modeldb_ids_to_check:
        result = check_doi_pmid(modeldb_id)
        if result:
            results.append(result)
        pbar.update(1)

# Create a DataFrame from the results
df = pd.DataFrame(results, columns=["ModelDB ID", "Identifier"])

# Save the results to a CSV file
output_file = "modeldb_doi_pmid_results.csv"
df.to_csv(output_file, index=False)

# Print entries with no DOI or PMID and count
no_identifier_entries = df[df["Identifier"].isna()]
print("Entries with no DOI or PMID:")
print(no_identifier_entries)

print(f"Data exported to CSV file: {output_file}")
print(f"Number of entries with no DOI or PMID: {len(no_identifier_entries)}")
# Out:
# Checking ModelDB Entries: 100%|██████████| 1842/1842 [06:26<00:00,  4.76it/s]
# Entries with no DOI or PMID:
# Empty DataFrame
# Columns: [ModelDB ID, Identifier]
# Index: []
# Data exported to CSV file: modeldb_doi_pmid_results.csv
# Number of entries with no DOI or PMID: 0

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from tqdm import tqdm

def check_doi_pmid(modeldb_id):
    url = f"https://modeldb.science/{modeldb_id}?tab=7"
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to retrieve data from {url}")
        return None

    soup = BeautifulSoup(response.text, 'html.parser')

    # Look for DOI or PMID in the webpage
    doi_element = soup.find("a", string="DOI")
    pmid_element = soup.find("a", string="PubMed")

    if doi_element:
        doi = doi_element.get("href")
        return modeldb_id, f"DOI: {doi}"
    elif pmid_element:
        pmid = pmid_element.get("href")
        return modeldb_id, f"PMID: {pmid}"
    else:
        return None

# Fetch the list of ModelDB IDs from the API
api_url = "https://modeldb.science/api/v1/models"
response = requests.get(api_url)
if response.status_code != 200:
    print(f"Failed to retrieve the list of ModelDB IDs from {api_url}")
    exit()

modeldb_ids_to_check = response.json()

# Initialize a list to store the results
results = []
skipped_entries = []

# Check all ModelDB entries for DOI or PMID and store the results
with tqdm(total=len(modeldb_ids_to_check), desc="Checking ModelDB Entries") as pbar:
    for modeldb_id in modeldb_ids_to_check:
        result = check_doi_pmid(modeldb_id)
        if result:
            results.append(result)
        else:
            skipped_entries.append(modeldb_id)
        pbar.update(1)

# Create a DataFrame from the results
df = pd.DataFrame(results, columns=["ModelDB ID", "Identifier"])

# Save the results to a CSV file
output_file = "modeldb_doi_pmid_results_1.csv"
df.to_csv(output_file, index=False)

# Print entries with no DOI or PMID and count
no_identifier_entries = df[df["Identifier"].isna()]
print("Entries with no DOI or PMID:")
print(no_identifier_entries)

# Print skipped entries and their count
print("Skipped entries (missing information):")
print(skipped_entries)
print(f"Number of skipped entries: {len(skipped_entries)}")
# Out:
# Checking ModelDB Entries: 100%|██████████| 1842/1842 [06:01<00:00,  5.10it/s]
# Entries with no DOI or PMID:
# Empty DataFrame
# Columns: [ModelDB ID, Identifier]
# Index: []
# Skipped entries (missing information):
# [36861, 36869, 128068, 136097, 181035, 182129, 185334, 190565, 224843, 230329, 230929, 231105, 244688, 245071, 245415, 246546, 247179, 247968, 249405, 254217, 259620, 260178, 260967, 261435, 261460, 261489, 261864, 261881, 262046, 262356, 263053, 263703, 263719, 264591, 266526, 266551, 266577, 266718, 266726, 266770, 266802, 266807, 266823, 266848, 266849, 266863, 266868, 266880, 266881, 266910, 266925, 266928, 266929, 267009, 267018, 267026, 267035, 267047, 267050, 267066, 267128, 267139, 267174, 267183, 267184, 267221, 267222, 267280, 267297, 267306, 267307, 267324, 267334, 267338, 267339, 267357, 267363, 267510, 267512, 267552, 267563, 267586, 267587, 267594, 267595, 267610, 267611, 267617, 267666, 267680, 267682, 267686, 267589, 267596, 267614, 267735, 267738, 260015, 266797, 2014814, 267591, 267620, 267144, 2014825, 267618, 267768, 2015414, 2014996, 2015413, 2015412, 2015421, 2014998, 2014833, 267613, 2014816]
# Number of skipped entries: 115

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from tqdm import tqdm

def get_model_details(modeldb_id):
    url = f"https://modeldb.science/{modeldb_id}?tab=7"
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Failed to retrieve data from {url}")
        return None

    soup = BeautifulSoup(response.text, 'html.parser')

    # Extract additional details for the skipped entry
    model_name_element = soup.find("h1", class_="blue")
    if model_name_element:
        model_name = model_name_element.text.strip()
    else:
        model_name = "N/A"

    return {
        "ModelDB ID": modeldb_id,
        "Model Name": model_name
    }

# Fetch the list of ModelDB IDs from the API
api_url = "https://modeldb.science/api/v1/models"
response = requests.get(api_url)
if response.status_code != 200:
    print(f"Failed to retrieve the list of ModelDB IDs from {api_url}")
    exit()

modeldb_ids_to_check = response.json()

# Initialize a list to store the skipped entries
skipped_entries = []

# Initialize a list to store additional details for skipped entries
skipped_entries_details = []

# Check all ModelDB entries for DOI or PMID and store the skipped entries
with tqdm(total=len(modeldb_ids_to_check), desc="Checking ModelDB Entries") as pbar:
    for modeldb_id in modeldb_ids_to_check:
        result = check_doi_pmid(modeldb_id)
        if not result:
            skipped_entries.append(modeldb_id)
            # Retrieve additional details for the skipped entry
            details = get_model_details(modeldb_id)
            if details:
                skipped_entries_details.append(details)
        pbar.update(1)

# Print entries with no DOI or PMID and count
print("Entries with no DOI or PMID:")
print(no_identifier_entries)

# Print skipped entries and their count
print("Skipped entries (missing information):")
print(skipped_entries)
print(f"Number of skipped entries: {len(skipped_entries)}")

# Print additional details for skipped entries
print("Additional details for skipped entries:")
for entry in skipped_entries_details:
    print(f"ModelDB ID: {entry['ModelDB ID']}, Model Name: {entry['Model Name']}")
# Out:
# Checking ModelDB Entries: 100%|██████████| 1842/1842 [07:15<00:00,  4.23it/s]
# Entries with no DOI or PMID:
# Empty DataFrame
# Columns: [ModelDB ID, Identifier]
# Index: []
# Skipped entries (missing information):
# [36861, 36869, 128068, 136097, 181035, 182129, 185334, 190565, 224843, 230329, 230929, 231105, 244688, 245071, 245415, 246546, 247179, 247968, 249405, 254217, 259620, 260178, 260967, 261435, 261460, 261489, 261864, 261881, 262046, 262356, 263053, 263703, 263719, 264591, 266526, 266551, 266577, 266718, 266726, 266770, 266802, 266807, 266823, 266848, 266849, 266863, 266868, 266880, 266881, 266910, 266925, 266928, 266929, 267009, 267018, 267026, 267035, 267047, 267050, 267066, 267128, 267139, 267174, 267183, 267184, 267221, 267222, 267280, 267297, 267306, 267307, 267324, 267334, 267338, 267339, 267357, 267363, 267510, 267512, 267552, 267563, 267586, 267587, 267594, 267595, 267610, 267611, 267617, 267666, 267680, 267682, 267686, 267589, 267596, 267614, 267735, 267738, 260015, 266797, 2014814, 267591, 267620, 267144, 2014825, 267618, 267768, 2015414, 2014996, 2015413, 2015412, 2015421, 2014998, 2014833, 267613, 2014816]
# Number of skipped entries: 115
# Additional details for skipped entries:
# ModelDB ID: 36861, Model Name: N/A
# ModelDB ID: 36869, Model Name: N/A
# ModelDB ID: 128068, Model Name: N/A
# ModelDB ID: 136097, Model Name: N/A
# ModelDB ID: 181035, Model Name: N/A
# ModelDB ID: 182129, Model Name: N/A
# ModelDB ID: 185334, Model Name: N/A
# ModelDB ID: 190565, Model Name: N/A
# ModelDB ID: 224843, Model Name: N/A
# ModelDB ID: 230329, Model Name: N/A
# ModelDB ID: 230929, Model Name: N/A
# ModelDB ID: 231105, Model Name: N/A
# ModelDB ID: 244688, Model Name: N/A
# ModelDB ID: 245071, Model Name: N/A
# ModelDB ID: 245415, Model Name: N/A
# ModelDB ID: 246546, Model Name: N/A
# ModelDB ID: 247179, Model Name: N/A
# ModelDB ID: 247968, Model Name: N/A
# ModelDB ID: 249405, Model Name: N/A
# ModelDB ID: 254217, Model Name: N/A
# ModelDB ID: 259620, Model Name: N/A
# ModelDB ID: 260178, Model Name: N/A
# ModelDB ID: 260967, Model Name: N/A
# ModelDB ID: 261435, Model Name: N/A
# ModelDB ID: 261460, Model Name: N/A
# ModelDB ID: 261489, Model Name: N/A
# ModelDB ID: 261864, Model Name: N/A
# ModelDB ID: 261881, Model Name: N/A
# ModelDB ID: 262046, Model Name: N/A
# ModelDB ID: 262356, Model Name: N/A
# ModelDB ID: 263053, Model Name: N/A
# ModelDB ID: 263703, Model Name: N/A
# ModelDB ID: 263719, Model Name: N/A
# ModelDB ID: 264591, Model Name: N/A
# ModelDB ID: 266526, Model Name: N/A
# ModelDB ID: 266551, Model Name: N/A
# ModelDB ID: 266577, Model Name: N/A
# ModelDB ID: 266718, Model Name: N/A
# ModelDB ID: 266726, Model Name: N/A
# ModelDB ID: 266770, Model Name: N/A
# ModelDB ID: 266802, Model Name: N/A
# ModelDB ID: 266807, Model Name: N/A
# ModelDB ID: 266823, Model Name: N/A
# ModelDB ID: 266848, Model Name: N/A
# ModelDB ID: 266849, Model Name: N/A
# ModelDB ID: 266863, Model Name: N/A
# ModelDB ID: 266868, Model Name: N/A
# ModelDB ID: 266880, Model Name: N/A
# ModelDB ID: 266881, Model Name: N/A
# ModelDB ID: 266910, Model Name: N/A
# ModelDB ID: 266925, Model Name: N/A
# ModelDB ID: 266928, Model Name: N/A
# ModelDB ID: 266929, Model Name: N/A
# ModelDB ID: 267009, Model Name: N/A
# ModelDB ID: 267018, Model Name: N/A
# ModelDB ID: 267026, Model Name: N/A
# ModelDB ID: 267035, Model Name: N/A
# ModelDB ID: 267047, Model Name: N/A
# ModelDB ID: 267050, Model Name: N/A
# ModelDB ID: 267066, Model Name: N/A
# ModelDB ID: 267128, Model Name: N/A
# ModelDB ID: 267139, Model Name: N/A
# ModelDB ID: 267174, Model Name: N/A
# ModelDB ID: 267183, Model Name: N/A
# ModelDB ID: 267184, Model Name: N/A
# ModelDB ID: 267221, Model Name: N/A
# ModelDB ID: 267222, Model Name: N/A
# ModelDB ID: 267280, Model Name: N/A
# ModelDB ID: 267297, Model Name: N/A
# ModelDB ID: 267306, Model Name: N/A
# ModelDB ID: 267307, Model Name: N/A
# ModelDB ID: 267324, Model Name: N/A
# ModelDB ID: 267334, Model Name: N/A
# ModelDB ID: 267338, Model Name: N/A
# ModelDB ID: 267339, Model Name: N/A
# ModelDB ID: 267357, Model Name: N/A
# ModelDB ID: 267363, Model Name: N/A
# ModelDB ID: 267510, Model Name: N/A
# ModelDB ID: 267512, Model Name: N/A
# ModelDB ID: 267552, Model Name: N/A
# ModelDB ID: 267563, Model Name: N/A
# ModelDB ID: 267586, Model Name: N/A
# ModelDB ID: 267587, Model Name: N/A
# ModelDB ID: 267594, Model Name: N/A
# ModelDB ID: 267595, Model Name: N/A
# ModelDB ID: 267610, Model Name: N/A
# ModelDB ID: 267611, Model Name: N/A
# ModelDB ID: 267617, Model Name: N/A
# ModelDB ID: 267666, Model Name: N/A
# ModelDB ID: 267680, Model Name: N/A
# ModelDB ID: 267682, Model Name: N/A
# ModelDB ID: 267686, Model Name: N/A
# ModelDB ID: 267589, Model Name: N/A
# ModelDB ID: 267596, Model Name: N/A
# ModelDB ID: 267614, Model Name: N/A
# ModelDB ID: 267735, Model Name: N/A
# ModelDB ID: 267738, Model Name: N/A
# ModelDB ID: 260015, Model Name: N/A
# ModelDB ID: 266797, Model Name: N/A
# ModelDB ID: 2014814, Model Name: N/A
# ModelDB ID: 267591, Model Name: N/A
# ModelDB ID: 267620, Model Name: N/A
# ModelDB ID: 267144, Model Name: N/A
# ModelDB ID: 2014825, Model Name: N/A
# ModelDB ID: 267618, Model Name: N/A
# ModelDB ID: 267768, Model Name: N/A
# ModelDB ID: 2015414, Model Name: N/A
# ModelDB ID: 2014996, Model Name: N/A
# ModelDB ID: 2015413, Model Name: N/A
# ModelDB ID: 2015412, Model Name: N/A
# ModelDB ID: 2015421, Model Name: N/A
# ModelDB ID: 2014998, Model Name: N/A
# ModelDB ID: 2014833, Model Name: N/A
# ModelDB ID: 267613, Model Name: N/A
# ModelDB ID: 2014816, Model Name: N/A

# %%
import csv

data = [
    36861, 36869, 128068, 136097, 181035, 182129, 185334, 190565, 224843, 230329, 230929, 231105, 244688, 245071, 245415,
    246546, 247179, 247968, 249405, 254217, 259620, 260178, 260967, 261435, 261460, 261489, 261864, 261881, 262046,
    262356, 263053, 263703, 263719, 264591, 266526, 266551, 266577, 266718, 266726, 266770, 266802, 266807, 266823,
    266848, 266849, 266863, 266868, 266880, 266881, 266910, 266925, 266928, 266929, 267009, 267018, 267026, 267035,
    267047, 267050, 267066, 267128, 267139, 267174, 267183, 267184, 267221, 267222, 267280, 267297, 267306, 267307,
    267324, 267334, 267338, 267339, 267357, 267363, 267510, 267512, 267552, 267563, 267586, 267587, 267594, 267595,
    267610, 267611, 267617, 267666, 267680, 267682, 267686, 267589, 267596, 267614, 267735, 267738, 260015, 266797,
    2014814, 267591, 267620, 267144, 2014825, 267618, 267768, 2015414, 2014996, 2015413, 2015412, 2015421, 2014998,
    2014833, 267613, 2014816
]

# Define the CSV file name
csv_file_name = "no_pmid.csv"

# Write the data to the CSV file
with open(csv_file_name, mode='w', newline='') as csv_file:
    csv_writer = csv.writer(csv_file)
    csv_writer.writerow(["Values"])  # Write a header row
    csv_writer.writerows(map(lambda x: [x], data))

print(f"Values have been saved to {csv_file_name}")
# Out:
# Values have been saved to no_pmid.csv
